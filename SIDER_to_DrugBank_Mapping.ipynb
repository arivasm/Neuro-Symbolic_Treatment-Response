# %%
import pubchempy

import os
import gzip
import collections
import xml.etree.ElementTree as ET
import pandas as pd

# %% [markdown]
# # Load drugbank database

# %%
xml_path = os.path.join('../../PhD_study/DDI_corpus/download', 'full database.xml.gz')
with gzip.open(xml_path) as xml_file:
    tree = ET.parse(xml_file)
root = tree.getroot()

# %%
ns = '{http://www.drugbank.ca}'
inchi_template = "{ns}calculated-properties/{ns}property[{ns}kind='InChI']/{ns}value"

rows = list()
not_inchi=0
for i, drug in enumerate(root):
    row = collections.OrderedDict()
    assert drug.tag == ns + 'drug'
    row['drugbank_id'] = drug.findtext(ns + "drugbank-id[@primary='true']")
    row['name'] = drug.findtext(ns + "name")
    #row['inchi'] = drug.findtext(inchi_template.format(ns = ns))
    if drug.findtext(inchi_template.format(ns = ns))==None:
        not_inchi+=1
        continue
    try:
        compounds = pubchempy.get_compounds(drug.findtext(inchi_template.format(ns = ns)), namespace='inchi')
    except pubchempy.BadRequestError:
        print('BadRequestError', row)
        continue
    compound, = compounds
    row['pubchem_id'] = compound.cid
    rows.append(row)
    #break
# Out:
# BadRequestError OrderedDict([('drugbank_id', 'DB00350'), ('name', 'Minoxidil')])
# BadRequestError OrderedDict([('drugbank_id', 'DB00475'), ('name', 'Chlordiazepoxide')])
# BadRequestError OrderedDict([('drugbank_id', 'DB02524'), ('name', "2',3'-O-{4-[Hydroxy(oxido)-λ5-azanylidene]-2,6-dinitro-2,5-cyclohexadiene-1,1-diyl}adenosine 5'-(tetrahydrogen triphosphate)")])
# BadRequestError OrderedDict([('drugbank_id', 'DB03382'), ('name', 'S-oxy-L-cysteine')])
# BadRequestError OrderedDict([('drugbank_id', 'DB03629'), ('name', "Pyridoxal-5'-Phosphate-N-Oxide")])
# BadRequestError OrderedDict([('drugbank_id', 'DB04722'), ('name', '2-[3-chloro-6-[2,2-difluoro-2-(1-oxidopyridin-1-ium-2-yl)ethyl]imino-1-hydroxypyridin-2-yl]-N-[(1R)-1-(3-chlorophenyl)ethyl]acetamide')])
# BadRequestError OrderedDict([('drugbank_id', 'DB04858'), ('name', 'Tirapazamine')])
# BadRequestError OrderedDict([('drugbank_id', 'DB05025'), ('name', 'Arimoclomol')])
# BadRequestError OrderedDict([('drugbank_id', 'DB06635'), ('name', 'Otamixaban')])
# BadRequestError OrderedDict([('drugbank_id', 'DB06815'), ('name', 'Pyrithione')])
# BadRequestError OrderedDict([('drugbank_id', 'DB07179'), ('name', '3-((3-bromo-5-o-tolylpyrazolo[1,5-a]pyrimidin-7-ylamino)methyl)pyridine 1-oxide')])
# BadRequestError OrderedDict([('drugbank_id', 'DB07550'), ('name', '2-(6-CHLORO-3-{[2,2-DIFLUORO-2-(1-OXIDO-2-PYRIDINYL)ETHYL]AMINO}-2-OXO-1(2H)-PYRAZINYL)-N-[(2-FLUOROPHENYL)METHYL]ACETAMIDE')])
# BadRequestError OrderedDict([('drugbank_id', 'DB07605'), ('name', '2-({4-[(5-CHLORO-1H-INDOL-2-YL)SULFONYL]PIPERAZIN-1-YL}CARBONYL)THIENO[3,2-B]PYRIDINE 4-OXIDE')])
# BadRequestError OrderedDict([('drugbank_id', 'DB07918'), ('name', '2-heptyl-4-hydroxyquinoline N-oxide')])
# BadRequestError OrderedDict([('drugbank_id', 'DB08276'), ('name', 'trifluoro-[hydroxy-[hydroxy-[2-(N-methyl-2-nitro-anilino)ethoxy]phosphoryl]oxy-phosphoryl]oxy-beryllium(1-)')])
# BadRequestError OrderedDict([('drugbank_id', 'DB08453'), ('name', '2-Nonyl-4-quinolinol 1-oxide')])
# BadRequestError OrderedDict([('drugbank_id', 'DB08559'), ('name', 'N-[(2S,4S,6R)-2-(dihydroxymethyl)-4-hydroxy-3,3-dimethyl-7-oxo-4lambda~4~-thia-1-azabicyclo[3.2.0]hept-6-yl]-2-phenylacetamide')])
# BadRequestError OrderedDict([('drugbank_id', 'DB08615'), ('name', '2-[4-(DIMETHYLAMINO)PHENYL]-6-HYDROXY-3-METHYL-1,3-BENZOTHIAZOL-3-IUM')])
# BadRequestError OrderedDict([('drugbank_id', 'DB08913'), ('name', 'Radium Ra 223 dichloride')])
# BadRequestError OrderedDict([('drugbank_id', 'DB09055'), ('name', 'Acipimox')])
# BadRequestError OrderedDict([('drugbank_id', 'DB09282'), ('name', 'Molsidomine')])
# BadRequestError OrderedDict([('drugbank_id', 'DB11327'), ('name', 'Dipyrithione')])
# BadRequestError OrderedDict([('drugbank_id', 'DB11632'), ('name', 'Opicapone')])
# BadRequestError OrderedDict([('drugbank_id', 'DB11838'), ('name', 'Revamilast')])
# BadRequestError OrderedDict([('drugbank_id', 'DB12021'), ('name', 'Dinaciclib')])
# BadRequestError OrderedDict([('drugbank_id', 'DB12648'), ('name', 'Nona-arginine')])
# BadRequestError OrderedDict([('drugbank_id', 'DB12706'), ('name', 'Seletalisib')])
# BadRequestError OrderedDict([('drugbank_id', 'DB12800'), ('name', 'CHF-6001')])
# BadRequestError OrderedDict([('drugbank_id', 'DB13006'), ('name', 'Cibinetide')])
# BadRequestError OrderedDict([('drugbank_id', 'DB13029'), ('name', 'MK-0873')])
# BadRequestError OrderedDict([('drugbank_id', 'DB13400'), ('name', 'Linsidomine')])
# BadRequestError OrderedDict([('drugbank_id', 'DB13486'), ('name', 'Magnesium peroxide')])
# BadRequestError OrderedDict([('drugbank_id', 'DB14492'), ('name', 'Potassium triiodide')])
# BadRequestError OrderedDict([('drugbank_id', 'DB14497'), ('name', 'Calcium magnesium potassium carbonate chloride hydroxide')])
# BadRequestError OrderedDict([('drugbank_id', 'DB14571'), ('name', 'Radium Ra-223 cation')])
# BadRequestError OrderedDict([('drugbank_id', 'DB14998'), ('name', 'Olorinab')])
# BadRequestError OrderedDict([('drugbank_id', 'DB15250'), ('name', 'Vercirnon')])
# BadRequestError OrderedDict([('drugbank_id', 'DB16301'), ('name', 'Preimplantation factor')])

# %%
not_inchi
# Out:
# 3294

# %%
columns = ['drugbank_id', 'name', 'pubchem_id']
drugbank_df = pd.DataFrame.from_dict(rows)[columns]
drugbank_df = drugbank_df[-drugbank_df.pubchem_id.isnull()]
drugbank_df['pubchem_id'] = drugbank_df['pubchem_id'].astype(int)
drugbank_df.to_csv('dataset/drugbank_cid.csv', index=False)
display(drugbank_df.shape, drugbank_df.head())
# Out:
# (11091, 3)
#   drugbank_id          name        cid
# 0     DB00006   Bivalirudin  101041682
# 1     DB00007    Leuprolide     657181
# 2     DB00014     Goserelin    5311128
# 4     DB00035  Desmopressin    5311065
# 5     DB00050    Cetrorelix   25074887

# %% [markdown]
# # STITCH to DrugBank mapping

# %%
def stitch_flat_to_pubchem(cid):
    assert cid.startswith('CID')
    return int(cid[3:]) - 1e8


def stitch_stereo_to_pubchem(cid):
    assert cid.startswith('CID')
    return int(cid[3:])

# %% [markdown]
# ### meddra_freq.tsv.gz

# %%
columns = ['stitch_id_flat', 'stitch_id_sterio', 'umls_cui_from_label', 'placebo', 'frequency', 'lower', 'upper',
           'meddra_type', 'umls_cui_from_meddra', 'side_effect_name',]
freq_df = pd.read_table('../../PhD_study/DDI_corpus/SIDER_data/meddra_freq.tsv.gz', names=columns)
freq_df.head(2)
# Out:
#   stitch_id_flat stitch_id_sterio umls_cui_from_label placebo frequency  \
# 0   CID100000085     CID000010917            C0000737     NaN       21%
# 1   CID100000085     CID000010917            C0000737     NaN       21%
#
#    lower  upper meddra_type umls_cui_from_meddra side_effect_name
# 0   0.21   0.21         LLT             C0000737   Abdominal pain
# 1   0.21   0.21          PT             C0000737   Abdominal pain

# %%
freq_df['pubchem_id'] = freq_df.stitch_id_sterio.map(stitch_stereo_to_pubchem)
freq_df = drugbank_df.merge(freq_df)
freq_df.to_csv('dataset/drugbank_side_effect.csv', index=False)
display(freq_df.shape, freq_df.head())
# Out:
# (203703, 13)
#   drugbank_id          name      cid stitch_id_flat stitch_id_sterio  \
# 0     DB00035  Desmopressin  5311065   CID100027991     CID005311065
# 1     DB00035  Desmopressin  5311065   CID100027991     CID005311065
# 2     DB00035  Desmopressin  5311065   CID100027991     CID005311065
# 3     DB00035  Desmopressin  5311065   CID100027991     CID005311065
# 4     DB00035  Desmopressin  5311065   CID100027991     CID005311065
#
#   umls_cui_from_label placebo frequency   lower   upper meddra_type  \
# 0            C0000737     NaN     0.65%  0.0065  0.0065         LLT
# 1            C0000737     NaN     0.65%  0.0065  0.0065          PT
# 2            C0000737     NaN     0.65%  0.0065  0.0065          PT
# 3            C0000737     NaN        1%  0.0100  0.0100         LLT
# 4            C0000737     NaN        1%  0.0100  0.0100          PT
#
#   umls_cui_from_meddra       side_effect_name
# 0             C0000737         Abdominal pain
# 1             C0000737         Abdominal pain
# 2             C0687713  Gastrointestinal pain
# 3             C0000737         Abdominal pain
# 4             C0000737         Abdominal pain

# %%
len(freq_df.drugbank_id.unique())
# Out:
# 663

# %%
len(freq_df.stitch_id_sterio.unique())
# Out:
# 1035

# %%
freq_df.stitch_id_sterio.unique()
# Out:
# array(['CID005311065', 'CID016131215', 'CID000006322', 'CID000005961',
#        'CID005280453', 'CID000000750', 'CID000054687', 'CID000060846',
#        'CID005362129', 'CID000082153', 'CID000002284', 'CID000089594',
#        'CID000003958', 'CID000059768', 'CID000387447', 'CID000034359',
#        'CID000002369', 'CID000003365', 'CID000005591', 'CID000065028',
#        'CID000002519', 'CID000071329', 'CID000447043', 'CID000060164',
#        'CID000004195', 'CID000004679', 'CID000041781', 'CID000002771',
#        'CID000077993', 'CID000003476', 'CID005362440', 'CID000053232',
#        'CID005486971', 'CID000005391', 'CID000004197', 'CID000004463',
#        'CID000020279', 'CID000056959', 'CID000004075', 'CID000054746',
#        'CID000002955', 'CID000441383', 'CID000001775', 'CID054671203',
#        'CID000002578', 'CID000004171', 'CID000005095', 'CID000003784',
#        'CID005284627', 'CID000158781', 'CID000002179', 'CID000002153',
#        'CID000005920', 'CID000003114', 'CID000003676', 'CID000005656',
#        'CID005282226', 'CID005360373', 'CID000002708', 'CID006917715',
#        'CID005288826', 'CID000002474', 'CID005481350', 'CID000021319',
#        'CID000005526', 'CID000150610', 'CID000005746', 'CID000082146',
#        'CID000002732', 'CID000003121', 'CID000060857', 'CID000001983',
#        'CID000123631', 'CID000043672', 'CID000010531', 'CID000002160',
#        'CID004659569', 'CID000009878', 'CID005284570', 'CID000003715',
#        'CID000004091', 'CID000002249', 'CID006509979', 'CID000004594',
#        'CID000002678', 'CID000039186', 'CID000002092', 'CID000115355',
#        'CID000002789', 'CID000008226', 'CID000166548', 'CID000013109',
#        'CID000060613', 'CID000004205', 'CID000033624', 'CID006918140',
#        'CID006337614', 'CID000004178', 'CID000071384', 'CID000002162',
#        'CID002724385', 'CID000004497', 'CID000002576', 'CID000005994',
#        'CID000216239', 'CID000068740', 'CID000004499', 'CID000969472',
#        'CID000002118', 'CID000003964', 'CID000446596', 'CID000051634',
#        'CID000004158', 'CID000005732', 'CID000003324', 'CID000029327',
#        'CID000000727', 'CID000006256', 'CID000145068', 'CID000446156',
#        'CID000005578', 'CID000452548', 'CID000041867', 'CID000003883',
#        'CID000003957', 'CID000004893', 'CID000003696', 'CID005284513',
#        'CID005362420', 'CID000004409', 'CID000003826', 'CID000016078',
#        'CID005281040', 'CID000003386', 'CID000005071', 'CID000216326',
#        'CID000005035', 'CID000002662', 'CID000002435', 'CID000018381',
#        'CID000005253', 'CID000002477', 'CID000441314', 'CID005281081',
#        'CID000035370', 'CID005284603', 'CID000003397', 'CID000002756',
#        'CID000003559', 'CID000392622', 'CID000041684', 'CID000014969',
#        'CID005360696', 'CID000002082', 'CID005484727', 'CID000449171',
#        'CID000004170', 'CID000065866', 'CID000176870', 'CID000002907',
#        'CID000005090', 'CID000002764', 'CID000004543', 'CID000002170',
#        'CID000003385', 'CID000004991', 'CID005311067', 'CID000002266',
#        'CID000005717', 'CID000001990', 'CID000439693', 'CID000004114',
#        'CID000003878', 'CID000006432', 'CID000060855', 'CID000104865',
#        'CID054686904', 'CID000126941', 'CID000002554', 'CID000004946',
#        'CID000174174', 'CID000003342', 'CID000002803', 'CID000119607',
#        'CID000071616', 'CID000010917', 'CID000444036', 'CID000003157',
#        'CID000006215', 'CID000060714', 'CID000003869', 'CID000441401',
#        'CID000006279', 'CID005361092', 'CID000002405', 'CID000005291',
#        'CID000031307', 'CID000006013', 'CID000064139', 'CID000002088',
#        'CID000119182', 'CID000012620', 'CID005311068', 'CID000060961',
#        'CID000054454', 'CID000036523', 'CID000004211', 'CID000018283',
#        'CID005311221', 'CID000005533', 'CID003085017', 'CID000071158',
#        'CID000002520', 'CID000004493', 'CID000005358', 'CID006321411',
#        'CID000009651', 'CID000003961', 'CID000005452', 'CID005280965',
#        'CID000004192', 'CID000036294', 'CID000062959', 'CID000037720',
#        'CID005281078', 'CID000005775', 'CID000016850', 'CID000030323',
#        'CID000003440', 'CID000005487', 'CID000443872', 'CID000065016',
#        'CID005360515', 'CID000005625', 'CID000129211', 'CID000041693',
#        'CID000060825', 'CID000060852', 'CID000006005', 'CID000043815',
#        'CID000050294', 'CID000060871', 'CID000025419', 'CID000057469',
#        'CID000004510', 'CID000441290', 'CID005311309', 'CID000047320',
#        'CID000005073', 'CID000047641', 'CID000004735', 'CID000005070',
#        'CID000005754', 'CID000006251', 'CID000060490', 'CID000004236',
#        'CID000002973', 'CID000003308', 'CID000003241', 'CID000005530',
#        'CID000003763', 'CID000444795', 'CID000060606', 'CID000441335',
#        'CID005281071', 'CID005280723', 'CID000036462', 'CID000034312',
#        'CID000005757', 'CID000156391', 'CID000107807', 'CID000002540',
#        'CID000005381', 'CID000051263', 'CID000003042', 'CID000004740',
#        'CID000003702', 'CID000037542', 'CID000003345', 'CID000004086',
#        'CID000110635', 'CID000003016', 'CID000055245', 'CID000003152',
#        'CID005311304', 'CID000015209', 'CID000006058', 'CID000005394',
#        'CID000000137', 'CID000005852', 'CID000003059', 'CID000445643',
#        'CID005284549', 'CID000005403', 'CID000151171', 'CID000444025',
#        'CID005281037', 'CID005284616', 'CID000060877', 'CID000005245',
#        'CID000002471', 'CID000004033', 'CID005284566', 'CID000005556',
#        'CID000004595', 'CID005311027', 'CID000060648', 'CID000005734',
#        'CID005281104', 'CID000005479', 'CID000065981', 'CID000002130',
#        'CID000004173', 'CID005280360', 'CID000123606', 'CID003033825',
#        'CID000002895', 'CID000009444', 'CID005282381', 'CID000004011',
#        'CID000005152', 'CID000104741', 'CID000003331', 'CID000003348',
#        'CID000004440', 'CID000005078', 'CID005284569', 'CID000004828',
#        'CID000005719', 'CID000060726', 'CID000002216', 'CID000065999',
#        'CID000124087', 'CID000002099', 'CID000002267', 'CID000150311',
#        'CID000003108', 'CID003002190', 'CID000003948', 'CID000208902',
#        'CID005282379', 'CID000003410', 'CID000003494', 'CID000060198',
#        'CID000002265', 'CID000003446', 'CID000031703', 'CID000077992',
#        'CID000003639', 'CID000002083', 'CID000092253', 'CID000003657',
#        'CID000003902', 'CID000002478', 'CID000003825', 'CID000004174',
#        'CID000032798', 'CID000003519', 'CID000002370', 'CID000027661',
#        'CID000003333', 'CID000446541', 'CID000002161', 'CID000003749',
#        'CID000667490', 'CID000026757', 'CID000003339', 'CID000005426',
#        'CID000460612', 'CID000004054', 'CID000005379', 'CID000157920',
#        'CID000009642', 'CID000441300', 'CID000003672', 'CID000004891',
#        'CID000004539', 'CID000033613', 'CID000004634', 'CID000003478',
#        'CID000002802', 'CID000148192', 'CID000657237', 'CID000003305',
#        'CID000005665', 'CID003034010', 'CID000003219', 'CID005311181',
#        'CID000003899', 'CID000446157', 'CID000016362', 'CID000060953',
#        'CID000005210', 'CID000004189', 'CID000004485', 'CID000074989',
#        'CID006918296', 'CID000002375', 'CID000005029', 'CID000004829',
#        'CID000002585', 'CID000149096', 'CID000477468', 'CID000003158',
#        'CID000004449', 'CID000065863', 'CID000000444', 'CID000005401',
#        'CID000004583', 'CID000002754', 'CID000055283', 'CID000004915',
#        'CID000146570', 'CID000042890', 'CID000010607', 'CID005280954',
#        'CID000003690', 'CID000004932', 'CID000003151', 'CID000047811',
#        'CID000002749', 'CID000042113', 'CID005284604', 'CID000001978',
#        'CID000068844', 'CID000259331', 'CID000044093', 'CID005284583',
#        'CID000039147', 'CID000004212', 'CID000003373', 'CID000060464',
#        'CID000084029', 'CID000003406', 'CID000003261', 'CID000057363',
#        'CID000002187', 'CID006436173', 'CID005281004', 'CID000009433',
#        'CID000005002', 'CID005281042', 'CID000004168', 'CID000005743',
#        'CID000005206', 'CID000060795', 'CID005282411', 'CID000003463',
#        'CID000002801', 'CID000002351', 'CID000003759', 'CID000003724',
#        'CID003062316', 'CID000208908', 'CID005311066', 'CID004369359',
#        'CID000451668', 'CID000468595', 'CID000213039', 'CID000159269',
#        'CID000115237', 'CID005329102', 'CID000170361', 'CID003083544',
#        'CID000003637', 'CID003011155', 'CID000004845', 'CID000033255',
#        'CID000000813', 'CID000037464', 'CID000003730', 'CID000039042',
#        'CID000006167', 'CID000004456', 'CID000028417', 'CID006918155',
#        'CID000010413', 'CID000003380', 'CID005284543', 'CID000002441',
#        'CID000031401', 'CID000004999', 'CID006442177', 'CID000023925',
#        'CID000005468', 'CID000123619', 'CID000005780', 'CID000449193',
#        'CID005288783', 'CID000072081', 'CID003000226', 'CID000001003',
#        'CID000000700', 'CID000000311', 'CID000005453', 'CID003001028',
#        'CID003002977', 'CID000009880', 'CID000006018', 'CID006445540',
#        'CID000134018', 'CID000208898', 'CID000071301', 'CID000644241',
#        'CID006918537', 'CID000153994', 'CID003036505', 'CID000071360',
#        'CID000121892', 'CID006918638', 'CID006918554', 'CID000108150',
#        'CID003081361', 'CID009578005', 'CID003010818', 'CID011561674',
#        'CID000132971', 'CID000004184', 'CID000012035', 'CID005352062',
#        'CID000129228', 'CID000216416', 'CID011450633', 'CID005312125',
#        'CID006918456', 'CID000073303', 'CID000219024', 'CID000219078',
#        'CID009875401', 'CID005284594', 'CID009869929', 'CID000003009',
#        'CID000092974', 'CID000216235', 'CID006918289', 'CID000002159',
#        'CID024873435', 'CID009887712', 'CID011243969', 'CID006918493',
#        'CID005281107', 'CID009690109', 'CID000193962', 'CID005329098',
#        'CID003052762', 'CID010113978', 'CID000082148', 'CID010182969',
#        'CID005328940', 'CID006450551', 'CID000001727', 'CID000002366',
#        'CID000125017', 'CID006918558', 'CID000060860', 'CID000004436',
#        'CID000000247', 'CID000065628', 'CID009854073', 'CID001548943',
#        'CID000121396', 'CID000168924', 'CID000044564', 'CID000003998',
#        'CID000151075', 'CID000148121', 'CID000004775', 'CID025074470',
#        'CID005311236', 'CID000213046', 'CID009871419', 'CID009868491',
#        'CID016220172', 'CID017754356', 'CID003086674', 'CID000002972',
#        'CID024776445', 'CID006451164', 'CID011626560', 'CID013559281',
#        'CID010324367', 'CID010034073', 'CID025102847', 'CID054684141',
#        'CID042611257', 'CID010096344', 'CID009924495', 'CID011556711',
#        'CID009865528', 'CID009926791', 'CID011167602', 'CID015951529',
#        'CID024826799', 'CID005388906', 'CID009854489', 'CID024812758',
#        'CID010482134', 'CID000134780', 'CID011707110', 'CID044462760',
#        'CID010184653', 'CID011304743', 'CID016004692', 'CID003003141',
#        'CID045375808', 'CID000065492', 'CID005493444', 'CID024965990',
#        'CID011949646', 'CID023652731', 'CID000489181', 'CID011499245',
#        'CID024821094', 'CID025151504', 'CID009966051', 'CID010220503',
#        'CID000012555', 'CID000007187', 'CID005277135', 'CID000000598',
#        'CID000023978', 'CID000003741', 'CID000004695', 'CID024822371',
#        'CID015950376', 'CID000003736', 'CID000047528', 'CID000004810',
#        'CID006918182', 'CID000024450', 'CID005462501', 'CID000003738',
#        'CID000004274', 'CID000060751', 'CID006480466', 'CID005311051',
#        'CID000023982', 'CID000065856', 'CID000023951', 'CID005280363',
#        'CID000123600', 'CID005311101', 'CID000060172', 'CID000064929',
#        'CID000002541', 'CID000009416', 'CID005463984', 'CID000464205',
#        'CID000062956', 'CID005464096', 'CID005464097', 'CID000055331',
#        'CID000072022', 'CID000107994', 'CID000062965', 'CID000441336',
#        'CID000000923', 'CID011234049', 'CID000006238', 'CID009881504',
#        'CID000000271', 'CID000216210', 'CID000057166'], dtype=object)

# %%
freq_df.meddra_type.unique()
# Out:
# array(['LLT', 'PT', nan], dtype=object)

# %%
freq_side_effect = freq_df.drop(columns=['placebo', 'frequency', 'meddra_type', 'umls_cui_from_meddra'])
freq_side_effect.drop_duplicates(keep='first', inplace=True)
freq_side_effect
# Out:
#        drugbank_id                     name      cid stitch_id_flat  \
# 0          DB00035             Desmopressin  5311065   CID100027991
# 2          DB00035             Desmopressin  5311065   CID100027991
# 3          DB00035             Desmopressin  5311065   CID100027991
# 5          DB00035             Desmopressin  5311065   CID100027991
# 6          DB00035             Desmopressin  5311065   CID100027991
# ...            ...                      ...      ...            ...
# 203693     DB15351  Dihematoporphyrin ether    57166   CID100057166
# 203695     DB15351  Dihematoporphyrin ether    57166   CID100057166
# 203697     DB15351  Dihematoporphyrin ether    57166   CID100057166
# 203699     DB15351  Dihematoporphyrin ether    57166   CID100057166
# 203701     DB15351  Dihematoporphyrin ether    57166   CID100057166
#
#        stitch_id_sterio umls_cui_from_label     lower     upper  \
# 0          CID005311065            C0000737  0.006500  0.006500
# 2          CID005311065            C0000737  0.006500  0.006500
# 3          CID005311065            C0000737  0.010000  0.010000
# 5          CID005311065            C0000737  0.010000  0.010000
# 6          CID005311065            C0000737  0.020000  0.020000
# ...                 ...                 ...       ...       ...
# 203693     CID000057166            C1536009  0.080000  0.080000
# 203695     CID000057166            C3263723  0.144928  0.144928
# 203697     CID000057166            C3263723  0.191781  0.191781
# 203699     CID000057166            C3263723  0.191824  0.191824
# 203701     CID000057166            C3263723  0.191919  0.191919
#
#              side_effect_name
# 0              Abdominal pain
# 2       Gastrointestinal pain
# 3              Abdominal pain
# 5       Gastrointestinal pain
# 6              Abdominal pain
# ...                       ...
# 203693     Oesophageal oedema
# 203695                 Injury
# 203697                 Injury
# 203699                 Injury
# 203701                 Injury
#
# [110602 rows x 9 columns]

# %%
freq_side_effect = freq_side_effect.sort_values('upper', ascending=False).drop_duplicates(['umls_cui_from_label'])
freq_side_effect
# Out:
#        drugbank_id           name     cid stitch_id_flat stitch_id_sterio  \
# 118850     DB00938     Salmeterol    5152   CID100005152     CID000005152
# 119470     DB00949      Felbamate    3331   CID100003331     CID000003331
# 119404     DB00949      Felbamate    3331   CID100003331     CID000003331
# 119383     DB00949      Felbamate    3331   CID100003331     CID000003331
# 119369     DB00949      Felbamate    3331   CID100003331     CID000003331
# ...            ...            ...     ...            ...              ...
# 59021      DB00537  Ciprofloxacin    2764   CID100002764     CID000002764
# 62579      DB00564  Carbamazepine    2554   CID100002554     CID000002554
# 59032      DB00537  Ciprofloxacin    2764   CID100002764     CID000002764
# 110724     DB00864     Tacrolimus  445643   CID100005372     CID000445643
# 111244     DB00872     Conivaptan  151171   CID100151171     CID000151171
#
#        umls_cui_from_label  lower   upper           side_effect_name
# 118850            C0040822   0.01  1.0000                     Tremor
# 119470            C0085631   0.01  1.0000                  Agitation
# 119404            C0039231   0.01  1.0000                Tachycardia
# 119383            C0033774   0.01  1.0000                   Pruritus
# 119369            C0030252   0.01  1.0000               Palpitations
# ...                    ...    ...     ...                        ...
# 59021             C0852388   0.00  0.0001  Visual colour distortions
# 62579             C0005944   0.00  0.0001   Bone metabolism disorder
# 59032             C0857751   0.00  0.0001  Erythema multiforme minor
# 110724            C0476369   0.00  0.0001    Echocardiogram abnormal
# 111244            C1112773   0.00  0.0000  Post procedural diarrhoea
#
# [3350 rows x 9 columns]

# %%
freq_side_effect.to_csv('dataset/drugbank_side_effect.csv', index=False)
