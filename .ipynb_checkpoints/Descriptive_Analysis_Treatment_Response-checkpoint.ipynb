# %%
import pandas as pd
import numpy as np
import deductive_system
import treatmentKG

import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.colors as colors
import matplotlib.colors as mcolors

# %%
input_path = 'Input/'

#negative_treatment = input_path + 'treatment_negative_effect.csv'
#positive_treatment = input_path + 'treatment_positive_effect.csv'

negative_treatment = 'dataset/Patient_negative.csv'
positive_treatment = 'dataset/Patient_positive.csv'

d_no_onco = input_path + 'patient_nonOncologycalTreatments.csv'

negative_treatment = pd.read_csv(negative_treatment, delimiter=",")
positive_treatment = pd.read_csv(positive_treatment, delimiter=",")
drug_no_onco = pd.read_csv(d_no_onco, delimiter=",")
ddi = deductive_system.load_dataset_ddi('../store_data/drug/Unsymmetric_DDI_corpus.csv')

drugBank_id_name = pd.read_csv('../store_data/drug/drugBank_id_name.csv', delimiter=",")

# %%
drug_no_onco = treatmentKG.preprocessing_nonOncological_drugs(drug_no_onco)
display(drug_no_onco.shape, drug_no_onco.head())
# Out:
# (1290, 2)
#    patient_id   drug_name
# 0     1098173  Omeprazole
# 1     1098173  Ranitidine
# 2     1100890  Omeprazole
# 3     1103334  Omeprazole
# 4     1103334   Enalapril

# %%
treatment = treatmentKG.preprocessing_oncological_drugs(positive_treatment)  #positive_treatment  negative_treatment
display(treatment.shape, treatment.head())
# Out:
# (419, 7)
#    patient_id   fecinitto   fecfintto                            tipoterapia  \
# 0        3561  2011-09-23  2012-01-02       Quimioterapia intravenosa y oral
# 1        3877  2009-03-27  2009-06-19       Quimioterapia intravenosa y oral
# 2        8359  2012-11-28  2013-02-11  Quimioterapia-Radioterapia secuencial
# 3        8359  2014-05-23  2014-06-13              Quimioterapia intravenosa
# 4       10701  2010-02-11  2010-07-16       Quimioterapia intravenosa y oral
#
#        ct_drug   ct_drug.1 ct_drug.2
# 0  Carboplatin   Etoposide       NaN
# 1  Carboplatin   Etoposide       NaN
# 2  Carboplatin  Paclitaxel       NaN
# 3   Pemetrexed         NaN       NaN
# 4  Carboplatin   Etoposide       NaN

# %%
treatment = treatmentKG.create_treatment(drug_no_onco, treatment)
treatment
# Out:
#      patient_id   fecinitto                                          drug_name
# 0          3561  2011-09-23  [Simvastatin, Acetaminophen, Omeprazole, Carbo...
# 1          3877  2009-03-27     [Omeprazole, Atenolol, Carboplatin, Etoposide]
# 2          8359  2012-11-28              [Furosemide, Carboplatin, Paclitaxel]
# 3          8359  2014-05-23                           [Furosemide, Pemetrexed]
# 4         10701  2010-02-11                           [Carboplatin, Etoposide]
# ..          ...         ...                                                ...
# 405     2819894  2019-05-22  [Enalapril, Carboplatin, Pemetrexed, Pembroliz...
# 406     2826513  2019-07-19                         [Carboplatin, Vinorelbine]
# 407     2840900  2019-07-22                             [Cisplatin, Etoposide]
# 408     2846797  2020-09-18                           [Cisplatin, Vinorelbine]
# 409     2856772  2020-08-11                          [Carboplatin, Paclitaxel]
#
# [410 rows x 3 columns]

# %%
df_treatment, set_drugs = treatmentKG.preprocess_treatment(treatment, [])
display(df_treatment, set_drugs)
# Out:
#                                              drug_name  n_drugs
# 0    [Allopurinol, Atenolol, Carboplatin, Etoposide...      9.0
# 1    [Atenolol, Atorvastatin, Carboplatin, Enalapri...      8.0
# 2    [Acetaminophen, Allopurinol, Amlodipine, Atorv...      8.0
# 3    [Acetaminophen, Atenolol, Cyclophosphamide, Do...      7.0
# 4    [Atorvastatin, Carboplatin, Enalapril, Metform...      7.0
# ..                                                 ...      ...
# 185                              [Atenolol, Topotecan]      2.0
# 186                            [Atenolol, Osimertinib]      2.0
# 187                           [Paclitaxel, Ranitidine]      2.0
# 188                          [Osimertinib, Ranitidine]      2.0
# 189                             [Erlotinib, Ibuprofen]      2.0
#
# [190 rows x 2 columns]
# {'Acetaminophen',
#  'Afatinib',
#  'Alectinib',
#  'Allopurinol',
#  'Amlodipine',
#  'Amoxicillin',
#  'Atenolol',
#  'Atezolizumab',
#  'Atorvastatin',
#  'Azithromycin',
#  'Bavituximab',
#  'Bevacizumab',
#  'Brigatinib',
#  'Capecitabine',
#  'Carboplatin',
#  'Ceritinib',
#  'Cetuximab',
#  'Cisplatin',
#  'Crizotinib',
#  'Cyclophosphamide',
#  'Daratumumab',
#  'Dexamethasone',
#  'Docetaxel',
#  'Doxorubicin',
#  'Durvalumab',
#  'Emibetuzumab',
#  'Enalapril',
#  'Erlotinib',
#  'Etoposide',
#  'Fentanyl',
#  'Furosemide',
#  'Gefitinib',
#  'Gemcitabine',
#  'Human_immunoglobulin_g',
#  'Ibuprofen',
#  'Ipilimumab',
#  'Irinotecan',
#  'Levofloxacin',
#  'Lorazepam',
#  'Lormetazepam',
#  'Metformin',
#  'Methylprednisolone',
#  'Nintedanib',
#  'Nivolumab',
#  'Olaparib',
#  'Omeprazole',
#  'Ondansetron',
#  'Osimertinib',
#  'Paclitaxel',
#  'Pembrolizumab',
#  'Pemetrexed',
#  'Prednisone',
#  'Ranitidine',
#  'Salbutamol',
#  'Simvastatin',
#  'Spironolactone',
#  'Topotecan',
#  'Tramadol',
#  'Vadimezan',
#  'Veliparib',
#  'Vincristine',
#  'Vinorelbine'}

# %%
pd.merge(positive, negative ,on='drug_name')
# Out:
#                                             drug_name
# 0   ['Cisplatin', 'Enalapril', 'Omeprazole', 'Simv...
# 1   ['Cisplatin', 'Omeprazole', 'Simvastatin', 'Vi...
# 2   ['Carboplatin', 'Enalapril', 'Etoposide', 'Ome...
# 3   ['Acetaminophen', 'Carboplatin', 'Etoposide', ...
# 4   ['Atorvastatin', 'Carboplatin', 'Omeprazole', ...
# ..                                                ...
# 67                      ['Paclitaxel', 'Simvastatin']
# 68                       ['Omeprazole', 'Pemetrexed']
# 69                       ['Nivolumab', 'Simvastatin']
# 70                       ['Paclitaxel', 'Ranitidine']
# 71                      ['Osimertinib', 'Ranitidine']
#
# [72 rows x 1 columns]

# %%
negative['drug_name'] = negative.drug_name.astype(str)
negative.dtypes
# Out:
# drug_name    object
# dtype: object

# %%
positive['drug_name'] = positive.drug_name.astype(str)
positive.dtypes
# Out:
# drug_name    object
# dtype: object

# %%
positive = df_treatment[['drug_name']]
positive
# Out:
#                                              drug_name
# 0    [Allopurinol, Atenolol, Carboplatin, Etoposide...
# 1    [Atenolol, Atorvastatin, Carboplatin, Enalapri...
# 2    [Acetaminophen, Allopurinol, Amlodipine, Atorv...
# 3    [Acetaminophen, Atenolol, Cyclophosphamide, Do...
# 4    [Atorvastatin, Carboplatin, Enalapril, Metform...
# ..                                                 ...
# 185                              [Atenolol, Topotecan]
# 186                            [Atenolol, Osimertinib]
# 187                           [Paclitaxel, Ranitidine]
# 188                          [Osimertinib, Ranitidine]
# 189                             [Erlotinib, Ibuprofen]
#
# [190 rows x 1 columns]

# %%
negative = df_treatment[['drug_name']]
negative
# Out:
#                                              drug_name
# 0    [Allopurinol, Atorvastatin, Carboplatin, Genta...
# 1    [Cyclophosphamide, Dexketoprofen, Doxorubicin,...
# 2    [Atenolol, Atorvastatin, Cyclophosphamide, Dox...
# 3    [Allopurinol, Atorvastatin, Gentamicin, Metfor...
# 4    [Acetaminophen, Atenolol, Atorvastatin, Carbop...
# ..                                                 ...
# 425                         [Simvastatin, Vinorelbine]
# 426                    [Cyclophosphamide, Vincristine]
# 427                         [Bevacizumab, Osimertinib]
# 428                             [Ceritinib, Enalapril]
# 429                         [Capecitabine, Omeprazole]
#
# [430 rows x 1 columns]

# %%
#col = list(colors.cnames.values())
#col = [col[9], col[3]]
col = [mcolors.CSS4_COLORS['brown'], mcolors.CSS4_COLORS['lightcoral']]
ax = sns.histplot(data=df_treatment, x='n_drugs', bins=5, legend=False, color=col[1])
ax.set_xlabel('Count of drugs')
ax.set_ylabel('Frequency of treatments')
plt.title('Histogram of count of drugs by Low-Effect Treatment')
plt.savefig('Embeddings/Plots/histogram_negative_treatment.pdf', format='pdf', bbox_inches='tight')
#plt.savefig("histogram_positive_treatment.png", format='png', bbox_inches='tight', dpi=300)

# %%
#col = list(colors.cnames.values())
#col = [col[9], col[3]]
col = [mcolors.CSS4_COLORS['brown'], mcolors.CSS4_COLORS['lightcoral']]
ax = sns.histplot(data=df_treatment, x='n_drugs', bins=5, legend=False, color=col[0])
ax.set_xlabel('Count of drugs')
ax.set_ylabel('Frequency of treatments')
plt.title('Histogram of count of drugs by Effective Treatment')
plt.savefig('Embeddings/Plots/histogram_positive_treatment.pdf', format='pdf', bbox_inches='tight')

# %%
df = pd.DataFrame(data=[[190],[430]], columns=['treatment'], index=['Effective Treatment', 'Low-Effect Treatment'])

ax = df['treatment'].plot(kind="bar", color=col, alpha=0.85,)
plt.xticks(rotation=0, horizontalalignment="center")
plt.ylabel('Count of treatments')
plt.title('Distribution of treatment responses')
plt.savefig('Embeddings/Plots/distribution_treatment.pdf', format='pdf', bbox_inches='tight')

# %%
drugBank_id = treatmentKG.get_drugbank_id(set_drugs, drugBank_id_name)
treatmentKG.generate_kg_treatment(df_treatment, drugBank_id, ddi, 190, 'negative')

# %%
drugBank_id = treatmentKG.get_drugbank_id(set_drugs, drugBank_id_name)
treatmentKG.generate_kg_treatment(df, drugBank_id, ddi, 6, 'positive')

# %%
df = df_treatment.iloc[20:30]
df = df.reset_index()
df = df.drop(columns=['index'])
df
# Out:
#                                         drug_name  n_drugs
# 0  [Atenolol, Carboplatin, Etoposide, Omeprazole]      4.0
# 1           [Atorvastatin, Gefitinib, Omeprazole]      3.0
# 2             [Atenolol, Carboplatin, Paclitaxel]      3.0
# 3             [Ibuprofen, Omeprazole, Paclitaxel]      3.0
# 4            [Carboplatin, Enalapril, Paclitaxel]      3.0
# 5         [Carboplatin, Simvastatin, Vinorelbine]      3.0
# 6             [Cisplatin, Omeprazole, Pemetrexed]      3.0
# 7        [Atorvastatin, Carboplatin, Vinorelbine]      3.0
# 8            [Cisplatin, Omeprazole, Vinorelbine]      3.0
# 9             [Atenolol, Atorvastatin, Docetaxel]      3.0

# %%
Atenolol, Carboplatin, Paclitaxel
Paclitaxel may decrease the excretion rate of Atenolol which could result in a higher serum level.
The risk or severity of adverse effects can be increased when Carboplatin is combined with Paclitaxel.

Carboplatin, Simvastatin, Vinorelbine
	The risk or severity of adverse effects can be increased when Vinorelbine is combined with Carboplatin.
    The metabolism of Simvastatin can be decreased when combined with Vinorelbine.

# %%
set_drugs = set(positive_treatment['ct_drug'].unique())
set_drugs.update(set(positive_treatment['ct_drug.1'].unique()))
set_drugs.update(set(positive_treatment['ct_drug.2'].unique()))
set_drugs
# Out:
# {'Afatinib',
#  'Carboplatino',
#  'Ciclofosfamida',
#  'Cisplatino',
#  'Docetaxel',
#  'Doxorrubicina',
#  'Durvalumab (MEDI4736)',
#  'Durvalumab(MEDI4736) vs Placebo',
#  'Erlotinib',
#  'Etopósido VP16',
#  'Gefitinib',
#  'Gemcitabina',
#  'Ipilimumab',
#  'Nivolumab',
#  'Osimertinib',
#  'Otro',
#  'Paclitaxel',
#  'Pembrolizumab vs placebo',
#  'Pemetrexed',
#  'Vadimezan (ASA404)',
#  'Vincristina',
#  'Vinorelbina',
#  nan}

# %%
drugBank_id_name = pd.read_csv('../store_data/drug/drugBank_id_name.csv', delimiter=",")
display(drugBank_id_name.shape, drugBank_id_name.head())
# Out:
# (14315, 2)
#   DrugBankID             DrugName
# 0    DB00001            Lepirudin
# 1    DB00002            Cetuximab
# 2    DB00003         Dornase_alfa
# 3    DB00004  Denileukin_diftitox
# 4    DB00005           Etanercept

# %%
drug_treatment = pd.DataFrame(set_drugs, columns=['DrugName'])
drugBank_id = pd.merge(drugBank_id_name, drug_treatment,on='DrugName')
#drug_id.to_csv('treatments/MIMIC_drugBank_id.csv', index=False)
drugBank_id
# Out:
#    DrugBankID                DrugName
# 0     DB00028  Human_immunoglobulin_g
# 1     DB00186               Lorazepam
# 2     DB00207            Azithromycin
# 3     DB00316           Acetaminophen
# 4     DB00317               Gefitinib
# 5     DB00335                Atenolol
# 6     DB00338              Omeprazole
# 7     DB00361             Vinorelbine
# 8     DB00381              Amlodipine
# 9     DB00421          Spironolactone
# 10    DB00437             Allopurinol
# 11    DB00441             Gemcitabine
# 12    DB00515               Cisplatin
# 13    DB00530               Erlotinib
# 14    DB00531        Cyclophosphamide
# 15    DB00541             Vincristine
# 16    DB00584               Enalapril
# 17    DB00641             Simvastatin
# 18    DB00642              Pemetrexed
# 19    DB00695              Furosemide
# 20    DB00773               Etoposide
# 21    DB00863              Ranitidine
# 22    DB00958             Carboplatin
# 23    DB00997             Doxorubicin
# 24    DB01050               Ibuprofen
# 25    DB01076            Atorvastatin
# 26    DB01229              Paclitaxel
# 27    DB01248               Docetaxel
# 28    DB06186              Ipilimumab
# 29    DB06235               Vadimezan
# 30    DB08916                Afatinib
# 31    DB09035               Nivolumab
# 32    DB09037           Pembrolizumab
# 33    DB09330             Osimertinib
# 34    DB11714              Durvalumab
# 35    DB13872            Lormetazepam

# %%
fix_name = drug_treatment.merge(drugBank_id, how = 'outer' , on='DrugName', indicator=True).loc[lambda x : x['_merge']=='left_only']
fix_name
# Out:
# Empty DataFrame
# Columns: [DrugName, DrugBankID, _merge]
# Index: []

# %%
fix_name.DrugName.values
# Out:
# array([nan, 'Carboplatino', 'Vinorelbina', 'Otro', 'Vadimezan (ASA404)',
#        'Gemcitabina', 'Vincristina', 'Durvalumab(MEDI4736) vs Placebo',
#        'Cisplatino', 'Doxorrubicina', 'Etopósido VP16', 'Ciclofosfamida',
#        'Durvalumab (MEDI4736)', 'Pembrolizumab vs placebo'], dtype=object)

# %%
list_d = df_treatment.drug_name[15]
list_d
# Out:
# ['Atenolol', 'Atorvastatin', 'Carboplatin', 'Vinorelbine']

# %%
input_data = drugBank_id.loc[drugBank_id.DrugName.isin(list_d)].DrugBankID.values
union, comorbidity_drug, set_DDIs = deductive_system.load_ddi(ddi, input_data)
union
# Out:
#   EffectorDrugLabel AffectedDrugLabel               Effect    Impact  \
# 0          Atenolol      Atorvastatin            excretion  decrease
# 1          Atenolol      Atorvastatin  serum_concentration  increase
# 2       Vinorelbine          Atenolol           metabolism  decrease
#
#   precipitantDrug objectDrug                 Effect_Impact
# 0         DB00335    DB01076            excretion_decrease
# 1         DB00335    DB01076  serum_concentration_increase
# 2         DB00361    DB00335           metabolism_decrease

# %%
g1, g2, g1_classified, g2_classified = deductive_system.capture_knowledge(union, comorbidity_drug, set_DDIs)
g2_classified
# Out:
#   EffectorDrugLabel AffectedDrugLabel                 Effect_Impact  \
# 0          Atenolol      Atorvastatin            excretion_decrease
# 1          Atenolol      Atorvastatin  serum_concentration_increase
# 2       Vinorelbine          Atenolol           metabolism_decrease
# 0       Vinorelbine      Atorvastatin            excretion_decrease
# 0       Vinorelbine      Atorvastatin  serum_concentration_increase
#
#             Class precipitantDrug objectDrug
# 0  HigherToxicity         DB00335    DB01076
# 1  HigherToxicity         DB00335    DB01076
# 2  HigherToxicity         DB00361    DB00335
# 0  HigherToxicity         DB00361    DB01076
# 0  HigherToxicity         DB00361    DB01076
