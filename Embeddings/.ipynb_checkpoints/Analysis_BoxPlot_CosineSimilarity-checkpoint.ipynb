# %%
import pandas as pd
from rdflib import Graph
from rdflib.plugins.sparql.processor import SPARQLResult

import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import seaborn as sns
import Auxiliary
import torch
import numpy as np

# %%
path = 'KG/V4/'

# %%
g1 = Graph()
g1.parse(path + "G1/train_4.ttl", format="ttl")

g2 = Graph()
g2.parse(path + "G2/train_4.ttl", format="ttl")
# Out:
# <Graph identifier=Nd8badfd887b44b2fb25df10e6d8c90fc (<class 'rdflib.graph.Graph'>)>

# %%
df = pd.read_csv(path + 'G2/train_5.ttl', delimiter='\t', header=None)
df['3'] = '.'
display(df.shape, df.head(2))
df.to_csv(path + 'G2/train_5.ttl', index=None, header=None, sep='\t')
# Out:
# (6566, 4)
#                                        0                1              2  3
# 0  <http://example/Treatment/treatment0>     ex:belong_to  ex:low_effect  .
# 1  <http://example/Treatment/treatment0>  ex:no_belong_to   ex:effective  .

# %%
def query_treatment_ddi_plot(treatement_list):
    query = """
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX ex: <http://example/> 

    select distinct ?treatment  (count(?ddi) as ?count_ddi)
    where {
        optional {?treatment ex:hasInteraction ?ddi .}
        FILTER (?treatment in ("""+treatement_list+"""))
        }
        GROUP BY ?treatment
        # ORDER BY desc(?count_ddi)
        """
    return query


def sparql_results_to_df(results: SPARQLResult) -> pd.DataFrame:
    """
    Export results from an rdflib SPARQL query into a `pandas.DataFrame`,
    using Python types. See https://github.com/RDFLib/rdflib/issues/1179.
    """
    return pd.DataFrame(
        data=([None if x is None else x.toPython() for x in row] for row in results),
        columns=[str(x) for x in results.vars],
    )

# %%
def get_treatment_ddi(response, path, g1, g2):
  df = pd.read_csv(path + 'G1/test_1.ttl', delimiter='\t', header=None)
  low_effect = list(df.loc[df[2]==response][0].values)
  query = query_treatment_ddi_plot(','.join(low_effect))  # 'ex:low_effect'

  qres = g1.query(query)
  df_g1 = sparql_results_to_df(qres)
  qres = g2.query(query)
  df_g2 = sparql_results_to_df(qres)

  df_g1['KG2'] = 0
  for i in range(df_g1.shape[0]):
    t = df_g1.iloc[i]['treatment']
    df_g1.at[i, 'KG2'] = df_g2.loc[df_g2.treatment==t].count_ddi.values[0]

  return df_g1

# %%
df_g1 = get_treatment_ddi('ex:low_effect', path, g1, g2)
df_g1.to_csv(path + 'treatment_low_effect.csv', index=None)
df_g1
# Out:
#                                 treatment  count_ddi  KG2
# 0     http://example/Treatment/treatment4         14   23
# 1     http://example/Treatment/treatment6         13   27
# 2    http://example/Treatment/treatment75          4    5
# 3   http://example/Treatment/treatment101          4    4
# 4   http://example/Treatment/treatment122          5    6
# ..                                    ...        ...  ...
# 61  http://example/Treatment/treatment391          1    1
# 62  http://example/Treatment/treatment398          1    1
# 63  http://example/Treatment/treatment289          1    1
# 64  http://example/Treatment/treatment330          1    1
# 65  http://example/Treatment/treatment346          1    1
#
# [66 rows x 3 columns]

# %%
df_g1 = pd.read_csv(path + 'treatment_low_effect.csv')
df_g1
# Out:
#                                 treatment  count_ddi  KG2
# 0     http://example/Treatment/treatment4         14   23
# 1     http://example/Treatment/treatment6         13   27
# 2    http://example/Treatment/treatment75          4    5
# 3   http://example/Treatment/treatment101          4    4
# 4   http://example/Treatment/treatment122          5    6
# ..                                    ...        ...  ...
# 61  http://example/Treatment/treatment391          1    1
# 62  http://example/Treatment/treatment398          1    1
# 63  http://example/Treatment/treatment289          1    1
# 64  http://example/Treatment/treatment330          1    1
# 65  http://example/Treatment/treatment346          1    1
#
# [66 rows x 3 columns]

# %%
t_low_effect = df_g1.loc[df_g1.KG2>df_g1.count_ddi]
t_low_effect['treatment'] = '<' + t_low_effect['treatment'].astype(str) + '>'
t_low_effect
# Out:
# C:\Users\rivasa\AppData\Local\Temp/ipykernel_18520/983812293.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t_low_effect['treatment'] = '<' + t_low_effect['treatment'].astype(str) + '>'
#                                   treatment  count_ddi  KG2
# 0     <http://example/Treatment/treatment4>         14   23
# 1     <http://example/Treatment/treatment6>         13   27
# 2    <http://example/Treatment/treatment75>          4    5
# 4   <http://example/Treatment/treatment122>          5    6
# 7    <http://example/Treatment/treatment13>          8   10
# 12   <http://example/Treatment/treatment62>          6    9
# 13   <http://example/Treatment/treatment91>          2    3
# 14   <http://example/Treatment/treatment97>          5    6
# 15  <http://example/Treatment/treatment149>          2    3
# 16   <http://example/Treatment/treatment80>          7    9
# 20   <http://example/Treatment/treatment36>          7   10
# 25  <http://example/Treatment/treatment215>          3    4
# 28   <http://example/Treatment/treatment59>          5    6
# 29    <http://example/Treatment/treatment8>         15   25
# 30   <http://example/Treatment/treatment53>         11   12
# 31   <http://example/Treatment/treatment76>          7    8
# 33  <http://example/Treatment/treatment317>          2    3
# 47   <http://example/Treatment/treatment41>          3    5
# 49   <http://example/Treatment/treatment94>          4    5
# 54  <http://example/Treatment/treatment306>          2    3
# 55  <http://example/Treatment/treatment287>          2    3

# %%
df_g1 = get_treatment_ddi('ex:effective', path, g1, g2)
df_g1.to_csv(path + 'treatment_effective.csv', index=None)
df_g1

# %%
df_g1 = pd.read_csv(path + 'treatment_effective.csv')
df_g1
# Out:
#                                 treatment  count_ddi  KG2
# 0   http://example/Treatment/treatment400          7   12
# 1   http://example/Treatment/treatment416          2    2
# 2   http://example/Treatment/treatment436          2    2
# 3   http://example/Treatment/treatment475          3    3
# 4   http://example/Treatment/treatment444          1    1
# 5   http://example/Treatment/treatment414          3    3
# 6   http://example/Treatment/treatment420          7   11
# 7   http://example/Treatment/treatment470          3    3
# 8   http://example/Treatment/treatment484          1    1
# 9   http://example/Treatment/treatment507          1    1
# 10  http://example/Treatment/treatment445          4    6
# 11  http://example/Treatment/treatment465          1    1
# 12  http://example/Treatment/treatment512          1    1
# 13  http://example/Treatment/treatment411          2    3
# 14  http://example/Treatment/treatment531          1    1
# 15  http://example/Treatment/treatment541          1    1
# 16  http://example/Treatment/treatment502          1    1
# 17  http://example/Treatment/treatment495          1    1

# %%
t_effective = df_g1.loc[df_g1.KG2>df_g1.count_ddi]

t_effective['treatment'] = '<' + t_effective['treatment'].astype(str) + '>'
t_effective
# Out:
# C:\Users\rivasa\AppData\Local\Temp/ipykernel_18520/1912915431.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t_effective['treatment'] = '<' + t_effective['treatment'].astype(str) + '>'
#                                   treatment  count_ddi  KG2
# 0   <http://example/Treatment/treatment400>          7   12
# 6   <http://example/Treatment/treatment420>          7   11
# 10  <http://example/Treatment/treatment445>          4    6
# 13  <http://example/Treatment/treatment411>          2    3

# %%
len(set(list(df_g1.treatment.unique()) + list(df_g2.treatment.unique())))
# Out:
# 66

# %%
m = 'TransH'  #RotatE
fold=1
graph = 'G1'
model = torch.load(path + graph+'/' + m + str(fold) + '/trained_model.pkl', map_location='cpu')
entity_embedding_tensor, relation_embedding_tensor =  Auxiliary.get_learned_embeddings(model)

tf_dataset, triple_dataset = Auxiliary.load_dataset(path, graph+'/data/train_1.ttl')
entity = list(t_effective.treatment.values)
df_predicted_entities, new_df = Auxiliary.create_dataframe_predicted_entities(entity_embedding_tensor, entity, tf_dataset)

# %%
entity_type = new_df[['target']]
entity_type['type'] = 'treatment'
entity_type = dict(entity_type[['target', 'type']].values)
# Out:
# C:\Users\rivasa\AppData\Local\Temp\ipykernel_29304\223779226.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   entity_type['type'] = 'treatment'

# %%
Auxiliary.plot_KGE(new_df, entity_type)

# %%
import numpy as np
from sklearn.decomposition import PCA

def PCA_1(X , num_components):
     
    #Step-1
    X_meaned = X - np.mean(X , axis = 0)
     
    #Step-2
    cov_mat = np.cov(X_meaned , rowvar = False)
     
    #Step-3
    eigen_values , eigen_vectors = np.linalg.eigh(cov_mat)
     
    #Step-4
    sorted_index = np.argsort(eigen_values)[::-1]
    sorted_eigenvalue = eigen_values[sorted_index]
    sorted_eigenvectors = eigen_vectors[:,sorted_index]
     
    #Step-5
    eigenvector_subset = sorted_eigenvectors[:,0:num_components]
     
    #Step-6
    X_reduced = np.dot(eigenvector_subset.transpose() , X_meaned.transpose() ).transpose()
     
    return X_reduced

def f_PCA(new_df , num_components):
    # Principal Component Analysis
    # define a matrix
    A = new_df.drop(columns='target')
    # create the PCA instance
    pca = PCA(2)
    # fit on data
    pca.fit(A)
    # transform data
    B = pca.transform(A)
    return B

def plot_treatment(new_df, response, graph):
    #df = new_df.drop(columns='target')
    df = f_PCA(new_df , 2)
    #plt.figure(figsize=(13,7))
    plt.scatter(df[:,0],df[:,1],linewidths=5,color='blue')
    plt.xlabel("PC1",size=15)
    plt.ylabel("PC2",size=15)
#     plt.ylim(-0.5, 0.6)
#     plt.xlim(-0.6, 0.7)
    plt.title(response+' Treatment Embedding Space',size=20)
    vocab=list(new_df.target.values)
    for i, word in enumerate(vocab):
        plt.annotate(word,xy=(df[i,0],df[i,1]))
    plt.savefig(fname='Plots/'+graph+response+'.pdf', format='pdf', bbox_inches='tight')
    plt.show()

# %%
plot_treatment(new_df, 'Effective', graph)

# %%
import Link_Prediction as lp
import scipy
from math import*
from decimal import Decimal
import seaborn as sns

# %%
th_lowEffect = 27.19266055 # means 399
th_effective = 72.80733945 # means 149

# %%
def get_TP_treatment(path, graph, fold, model, response, th):
    tf_testing, triple_test = lp.load_dataset(path, graph+'/test_'+str(fold)+'.ttl')
    predicted_heads_dec_eff = lp.predict_heads(model, 'ex:belong_to', response, tf_testing)
    threshold, threshold_index = lp.get_threshold(predicted_heads_dec_eff, th)
    tp_fp = predicted_heads_dec_eff.iloc[0:threshold_index + 1]
    fn_tn = predicted_heads_dec_eff.iloc[threshold_index+1:]
    fn = fn_tn.loc[fn_tn.in_training == True]
    tp = tp_fp.loc[tp_fp.in_training == True]
    return list(fn.head_label.values), list(tp.head_label.values)


def intersection_list(list1, list2):  
    return set(list1).intersection(list2)


def euclidean_distance(x,y):
    return sqrt(sum(pow(a-b,2) for a, b in zip(x, y)))

def manhattan_distance(x,y):
      return sum(abs(a-b) for a,b in zip(x,y))

def cosine_sim(x, y):
    return abs(1 - scipy.spatial.distance.cosine(x, y))

 
def nth_root(value, n_root):
    root_value = 1/float(n_root)
    return round (Decimal(value) ** Decimal(root_value),3)
 
def minkowski_distance(x,y,p_value):
    return nth_root(sum(pow(abs(a-b),p_value) for a,b in zip(x, y)),p_value)


def matrix_similarity(new_df, f_dist):
    array = new_df.set_index('target')
    entity = list(array.index.values)
    cosine_matrix = pd.DataFrame(index=entity, columns=entity)
    cosine_matrix = cosine_matrix.fillna(0.0)
    sim_val = 0

    for index, row in array.iterrows():
        for indexC, rowC in array.iterrows():
            sim = f_dist(row.values, rowC.values)
            sim = round(sim, 5)
            cosine_matrix.at[index, indexC] = sim
            if sim > sim_val and index != indexC:
                sim_val = sim
    return cosine_matrix, sim_val

def normalize_matrix(sim_matrix):
    max_val = max(sim_matrix.max())
    sim_matrix = 1 - sim_matrix.div(max_val)
    return sim_matrix

# %%
fold=4
m = 'TransH'
graph = 'G1'
model_g1 = torch.load(path + graph+'/' + m + str(fold) + '/trained_model.pkl', map_location='cpu')
g1_fn, g1_tp = get_TP_treatment(path, graph, fold, model_g1, 'ex:low_effect', th_lowEffect) # 'ex:low_effect'   'ex:effective'
graph = 'G2'
model_g2 = torch.load(path + graph+'/' + m + str(fold) + '/trained_model.pkl', map_location='cpu')
g2_fn, g2_tp = get_TP_treatment(path, graph, fold, model_g2, 'ex:low_effect', th_lowEffect)

# %%
intersection_list(g1_fn, g2_tp)
# Out:
# {'<http://example/Treatment/treatment102>',
#  '<http://example/Treatment/treatment225>',
#  '<http://example/Treatment/treatment312>',
#  '<http://example/Treatment/treatment350>',
#  '<http://example/Treatment/treatment355>'}

# %%
graph = 'G1'
entity_embedding_tensor, relation_embedding_tensor =  Auxiliary.get_learned_embeddings(model_g1)
tf_dataset, triple_dataset = Auxiliary.load_dataset(path, graph+'/data/train_'+str(fold)+'.ttl')
entity = list(intersection_list(g1_fn, g2_tp))+['ex:low_effect']
df_predicted_entities, new_df, df_g1 = Auxiliary.create_dataframe_predicted_entities(entity_embedding_tensor, entity,
                                                                                     tf_dataset)
new_df.replace('<http://example/Treatment/', '', regex=True, inplace=True)
new_df.replace('>', '', regex=True, inplace=True)
plot_treatment(new_df, 'Low_effect', graph)

# %%
cosine_matrix, sim_val = matrix_similarity(new_df, cosine_sim)
summatory = sum(cosine_matrix.sum().values)
avg_sim = (summatory - cosine_matrix.shape[0]) / (cosine_matrix.shape[0]*(cosine_matrix.shape[0]-1))
display(sum(cosine_matrix.sum().values), avg_sim, cosine_matrix)
# Out:
# 21.25904
# 0.5086346666666667
#                treatment102  treatment225  treatment312  treatment350  \
# treatment102        1.00000       0.54485       0.29405       0.41346
# treatment225        0.54485       1.00000       0.51776       0.39409
# treatment312        0.29405       0.51776       1.00000       0.45444
# treatment350        0.41346       0.39409       0.45444       1.00000
# treatment355        0.50081       0.56162       0.43885       0.56456
# ex:low_effect       0.62688       0.56605       0.46797       0.68619
#
#                treatment355  ex:low_effect
# treatment102        0.50081        0.62688
# treatment225        0.56162        0.56605
# treatment312        0.43885        0.46797
# treatment350        0.56456        0.68619
# treatment355        1.00000        0.59794
# ex:low_effect       0.59794        1.00000

# %%
graph = 'G2'
entity_embedding_tensor, relation_embedding_tensor =  Auxiliary.get_learned_embeddings(model_g2)
tf_dataset, triple_dataset = Auxiliary.load_dataset(path, graph+'/data/train_'+str(fold)+'.ttl')
entity = list(intersection_list(g1_fn, g2_tp))+['ex:low_effect']
df_predicted_entities, new_df, df_g2 = Auxiliary.create_dataframe_predicted_entities(entity_embedding_tensor, entity,
                                                                                     tf_dataset)
new_df.replace('<http://example/Treatment/', '', regex=True, inplace=True)
new_df.replace('>', '', regex=True, inplace=True)
plot_treatment(new_df, 'Low_effect', graph)
# Out:
# C:\Users\rivasa\Anaconda3\lib\site-packages\pandas\core\frame.py:5238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
cosine_matrix_g2, sim_val = matrix_similarity(new_df, cosine_sim)
summatory = sum(cosine_matrix_g2.sum().values)
avg_sim = (summatory - cosine_matrix_g2.shape[0]) / (cosine_matrix_g2.shape[0]*(cosine_matrix_g2.shape[0]-1))
display(sum(cosine_matrix_g2.sum().values), avg_sim, cosine_matrix_g2)
# Out:
# 21.902519999999996
# 0.5300839999999999
#                treatment102  treatment225  treatment312  treatment350  \
# treatment102        1.00000       0.53250       0.31150       0.46372
# treatment225        0.53250       1.00000       0.54906       0.42141
# treatment312        0.31150       0.54906       1.00000       0.49781
# treatment350        0.46372       0.42141       0.49781       1.00000
# treatment355        0.53822       0.56491       0.47320       0.59578
# ex:low_effect       0.63444       0.56063       0.48099       0.71017
#
#                treatment355  ex:low_effect
# treatment102        0.53822        0.63444
# treatment225        0.56491        0.56063
# treatment312        0.47320        0.48099
# treatment350        0.59578        0.71017
# treatment355        1.00000        0.61692
# ex:low_effect       0.61692        1.00000

# %%
cosine_matrix[['ex:low_effect']]
# Out:
#                ex:low_effect
# treatment102         0.62688
# treatment225         0.56605
# treatment312         0.46797
# treatment350         0.68619
# treatment355         0.59794
# ex:low_effect        1.00000

# %%
cosine_matrix_g2[['ex:low_effect']]
# Out:
#                ex:low_effect
# treatment102         0.63444
# treatment225         0.56063
# treatment312         0.48099
# treatment350         0.71017
# treatment355         0.61692
# ex:low_effect        1.00000

# %%
display('G1: ', cosine_matrix.loc['treatment225'], 'G2: ', cosine_matrix_g2.loc['treatment225'])
# Out:
# 'G1: '
# treatment102     0.54485
# treatment225     1.00000
# treatment312     0.51776
# treatment350     0.39409
# treatment355     0.56162
# ex:low_effect    0.56605
# Name: treatment225, dtype: float64
# 'G2: '
# treatment102     0.53250
# treatment225     1.00000
# treatment312     0.54906
# treatment350     0.42141
# treatment355     0.56491
# ex:low_effect    0.56063
# Name: treatment225, dtype: float64

# %% [markdown]
# ## Comparing one treatment with all the treatments of the same response

# %%
len(g1_fn)
# Out:
# 20

# %%
len(g1_tp)
# Out:
# 59

# %%
def query_treatment_by_class(response):
    query = """
    PREFIX ex: <http://example/> 

    select distinct ?treatment
    where {
        # ?treatment ex:belong_to """+response+""" .
        }
        """
    return query

# %%
qres = g1.query(query_treatment_by_class('ex:low_effect'))
treatment_response = sparql_results_to_df(qres)
treatment_response['treatment'] = '<' + treatment_response['treatment'].astype(str) + '>'
df = treatment_response.append({'treatment':entity[0]}, ignore_index=True)
df = list(df.treatment.values)

graph = 'G1'
entity_embedding_tensor, relation_embedding_tensor =  Auxiliary.get_learned_embeddings(model_g1)
tf_dataset, triple_dataset = Auxiliary.load_dataset(path, graph+'/data/train_'+str(fold)+'.ttl')
df_predicted_entities, new_df, df_g1 = Auxiliary.create_dataframe_predicted_entities(entity_embedding_tensor, df, tf_dataset)
new_df.replace('<http://example/Treatment/', '', regex=True, inplace=True)
new_df.replace('>', '', regex=True, inplace=True)
# Out:
# C:\Users\rivasa\Anaconda3\lib\site-packages\pandas\core\frame.py:5238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
set_difference = set(tf_dataset.entity_to_id) - set(df) - set(g1_tp) - set(g1_fn) - set('')
set_difference
# Out:
# {'<http://example/Drug/DB00002>',
#  '<http://example/Drug/DB00028>',
#  '<http://example/Drug/DB00112>',
#  '<http://example/Drug/DB00186>',
#  '<http://example/Drug/DB00193>',
#  '<http://example/Drug/DB00207>',
#  '<http://example/Drug/DB00316>',
#  '<http://example/Drug/DB00317>',
#  '<http://example/Drug/DB00331>',
#  '<http://example/Drug/DB00335>',
#  '<http://example/Drug/DB00338>',
#  '<http://example/Drug/DB00361>',
#  '<http://example/Drug/DB00381>',
#  '<http://example/Drug/DB00421>',
#  '<http://example/Drug/DB00437>',
#  '<http://example/Drug/DB00440>',
#  '<http://example/Drug/DB00441>',
#  '<http://example/Drug/DB00515>',
#  '<http://example/Drug/DB00530>',
#  '<http://example/Drug/DB00531>',
#  '<http://example/Drug/DB00537>',
#  '<http://example/Drug/DB00541>',
#  '<http://example/Drug/DB00584>',
#  '<http://example/Drug/DB00635>',
#  '<http://example/Drug/DB00641>',
#  '<http://example/Drug/DB00642>',
#  '<http://example/Drug/DB00695>',
#  '<http://example/Drug/DB00762>',
#  '<http://example/Drug/DB00773>',
#  '<http://example/Drug/DB00798>',
#  '<http://example/Drug/DB00813>',
#  '<http://example/Drug/DB00853>',
#  '<http://example/Drug/DB00863>',
#  '<http://example/Drug/DB00904>',
#  '<http://example/Drug/DB00958>',
#  '<http://example/Drug/DB00959>',
#  '<http://example/Drug/DB00997>',
#  '<http://example/Drug/DB01001>',
#  '<http://example/Drug/DB01015>',
#  '<http://example/Drug/DB01030>',
#  '<http://example/Drug/DB01050>',
#  '<http://example/Drug/DB01060>',
#  '<http://example/Drug/DB01076>',
#  '<http://example/Drug/DB01101>',
#  '<http://example/Drug/DB01137>',
#  '<http://example/Drug/DB01212>',
#  '<http://example/Drug/DB01225>',
#  '<http://example/Drug/DB01229>',
#  '<http://example/Drug/DB01233>',
#  '<http://example/Drug/DB01234>',
#  '<http://example/Drug/DB01248>',
#  '<http://example/Drug/DB05136>',
#  '<http://example/Drug/DB05487>',
#  '<http://example/Drug/DB06186>',
#  '<http://example/Drug/DB06235>',
#  '<http://example/Drug/DB07232>',
#  '<http://example/Drug/DB08865>',
#  '<http://example/Drug/DB08911>',
#  '<http://example/Drug/DB08912>',
#  '<http://example/Drug/DB08916>',
#  '<http://example/Drug/DB09035>',
#  '<http://example/Drug/DB09037>',
#  '<http://example/Drug/DB09063>',
#  '<http://example/Drug/DB09074>',
#  '<http://example/Drug/DB09079>',
#  '<http://example/Drug/DB09214>',
#  '<http://example/Drug/DB09330>',
#  '<http://example/Drug/DB09331>',
#  '<http://example/Drug/DB09559>',
#  '<http://example/Drug/DB11363>',
#  '<http://example/Drug/DB11595>',
#  '<http://example/Drug/DB11714>',
#  '<http://example/Drug/DB11746>',
#  '<http://example/Drug/DB11791>',
#  '<http://example/Drug/DB11849>',
#  '<http://example/Drug/DB12001>',
#  '<http://example/Drug/DB12008>',
#  '<http://example/Drug/DB12047>',
#  '<http://example/Drug/DB12130>',
#  '<http://example/Drug/DB12267>',
#  '<http://example/Drug/DB12674>',
#  '<http://example/Drug/DB12734>',
#  '<http://example/Drug/DB13137>',
#  '<http://example/Drug/DB13872>',
#  '<http://example/Treatment/treatment399>',
#  '<http://example/Treatment/treatment400>',
#  '<http://example/Treatment/treatment401>',
#  '<http://example/Treatment/treatment402>',
#  '<http://example/Treatment/treatment403>',
#  '<http://example/Treatment/treatment404>',
#  '<http://example/Treatment/treatment405>',
#  '<http://example/Treatment/treatment406>',
#  '<http://example/Treatment/treatment407>',
#  '<http://example/Treatment/treatment408>',
#  '<http://example/Treatment/treatment409>',
#  '<http://example/Treatment/treatment410>',
#  '<http://example/Treatment/treatment411>',
#  '<http://example/Treatment/treatment412>',
#  '<http://example/Treatment/treatment413>',
#  '<http://example/Treatment/treatment414>',
#  '<http://example/Treatment/treatment415>',
#  '<http://example/Treatment/treatment416>',
#  '<http://example/Treatment/treatment417>',
#  '<http://example/Treatment/treatment418>',
#  '<http://example/Treatment/treatment419>',
#  '<http://example/Treatment/treatment420>',
#  '<http://example/Treatment/treatment421>',
#  '<http://example/Treatment/treatment422>',
#  '<http://example/Treatment/treatment423>',
#  '<http://example/Treatment/treatment424>',
#  '<http://example/Treatment/treatment425>',
#  '<http://example/Treatment/treatment426>',
#  '<http://example/Treatment/treatment427>',
#  '<http://example/Treatment/treatment428>',
#  '<http://example/Treatment/treatment429>',
#  '<http://example/Treatment/treatment430>',
#  '<http://example/Treatment/treatment431>',
#  '<http://example/Treatment/treatment432>',
#  '<http://example/Treatment/treatment433>',
#  '<http://example/Treatment/treatment434>',
#  '<http://example/Treatment/treatment435>',
#  '<http://example/Treatment/treatment436>',
#  '<http://example/Treatment/treatment437>',
#  '<http://example/Treatment/treatment438>',
#  '<http://example/Treatment/treatment439>',
#  '<http://example/Treatment/treatment440>',
#  '<http://example/Treatment/treatment441>',
#  '<http://example/Treatment/treatment442>',
#  '<http://example/Treatment/treatment443>',
#  '<http://example/Treatment/treatment444>',
#  '<http://example/Treatment/treatment445>',
#  '<http://example/Treatment/treatment446>',
#  '<http://example/Treatment/treatment447>',
#  '<http://example/Treatment/treatment448>',
#  '<http://example/Treatment/treatment449>',
#  '<http://example/Treatment/treatment450>',
#  '<http://example/Treatment/treatment451>',
#  '<http://example/Treatment/treatment452>',
#  '<http://example/Treatment/treatment453>',
#  '<http://example/Treatment/treatment454>',
#  '<http://example/Treatment/treatment455>',
#  '<http://example/Treatment/treatment456>',
#  '<http://example/Treatment/treatment457>',
#  '<http://example/Treatment/treatment458>',
#  '<http://example/Treatment/treatment459>',
#  '<http://example/Treatment/treatment460>',
#  '<http://example/Treatment/treatment461>',
#  '<http://example/Treatment/treatment462>',
#  '<http://example/Treatment/treatment463>',
#  '<http://example/Treatment/treatment464>',
#  '<http://example/Treatment/treatment465>',
#  '<http://example/Treatment/treatment466>',
#  '<http://example/Treatment/treatment467>',
#  '<http://example/Treatment/treatment468>',
#  '<http://example/Treatment/treatment469>',
#  '<http://example/Treatment/treatment470>',
#  '<http://example/Treatment/treatment471>',
#  '<http://example/Treatment/treatment472>',
#  '<http://example/Treatment/treatment473>',
#  '<http://example/Treatment/treatment474>',
#  '<http://example/Treatment/treatment475>',
#  '<http://example/Treatment/treatment476>',
#  '<http://example/Treatment/treatment477>',
#  '<http://example/Treatment/treatment478>',
#  '<http://example/Treatment/treatment479>',
#  '<http://example/Treatment/treatment480>',
#  '<http://example/Treatment/treatment481>',
#  '<http://example/Treatment/treatment482>',
#  '<http://example/Treatment/treatment483>',
#  '<http://example/Treatment/treatment484>',
#  '<http://example/Treatment/treatment485>',
#  '<http://example/Treatment/treatment486>',
#  '<http://example/Treatment/treatment487>',
#  '<http://example/Treatment/treatment488>',
#  '<http://example/Treatment/treatment489>',
#  '<http://example/Treatment/treatment490>',
#  '<http://example/Treatment/treatment491>',
#  '<http://example/Treatment/treatment492>',
#  '<http://example/Treatment/treatment493>',
#  '<http://example/Treatment/treatment494>',
#  '<http://example/Treatment/treatment495>',
#  '<http://example/Treatment/treatment496>',
#  '<http://example/Treatment/treatment497>',
#  '<http://example/Treatment/treatment498>',
#  '<http://example/Treatment/treatment499>',
#  '<http://example/Treatment/treatment500>',
#  '<http://example/Treatment/treatment501>',
#  '<http://example/Treatment/treatment502>',
#  '<http://example/Treatment/treatment503>',
#  '<http://example/Treatment/treatment504>',
#  '<http://example/Treatment/treatment505>',
#  '<http://example/Treatment/treatment506>',
#  '<http://example/Treatment/treatment507>',
#  '<http://example/Treatment/treatment508>',
#  '<http://example/Treatment/treatment509>',
#  '<http://example/Treatment/treatment510>',
#  '<http://example/Treatment/treatment511>',
#  '<http://example/Treatment/treatment512>',
#  '<http://example/Treatment/treatment513>',
#  '<http://example/Treatment/treatment514>',
#  '<http://example/Treatment/treatment515>',
#  '<http://example/Treatment/treatment516>',
#  '<http://example/Treatment/treatment517>',
#  '<http://example/Treatment/treatment518>',
#  '<http://example/Treatment/treatment519>',
#  '<http://example/Treatment/treatment520>',
#  '<http://example/Treatment/treatment521>',
#  '<http://example/Treatment/treatment522>',
#  '<http://example/Treatment/treatment523>',
#  '<http://example/Treatment/treatment524>',
#  '<http://example/Treatment/treatment525>',
#  '<http://example/Treatment/treatment526>',
#  '<http://example/Treatment/treatment527>',
#  '<http://example/Treatment/treatment528>',
#  '<http://example/Treatment/treatment529>',
#  '<http://example/Treatment/treatment530>',
#  '<http://example/Treatment/treatment531>',
#  '<http://example/Treatment/treatment532>',
#  '<http://example/Treatment/treatment533>',
#  '<http://example/Treatment/treatment534>',
#  '<http://example/Treatment/treatment535>',
#  '<http://example/Treatment/treatment536>',
#  '<http://example/Treatment/treatment537>',
#  '<http://example/Treatment/treatment538>',
#  '<http://example/Treatment/treatment539>',
#  '<http://example/Treatment/treatment540>',
#  '<http://example/Treatment/treatment541>',
#  '<http://example/Treatment/treatment542>',
#  '<http://example/Treatment/treatment543>',
#  '<http://example/Treatment/treatment544>',
#  '<http://example/Treatment/treatment545>',
#  '<http://example/Treatment/treatment546>',
#  '<http://example/Treatment/treatment547>',
#  'ddi:DB00186DB00193',
#  'ddi:DB00186DB00316',
#  'ddi:DB00186DB00331',
#  'ddi:DB00186DB00335',
#  'ddi:DB00186DB00338',
#  'ddi:DB00186DB00361',
#  'ddi:DB00186DB00381',
#  'ddi:DB00186DB00437',
#  'ddi:DB00186DB00441',
#  'ddi:DB00186DB00515',
#  'ddi:DB00186DB00530',
#  'ddi:DB00186DB00541',
#  'ddi:DB00186DB00641',
#  'ddi:DB00186DB00642',
#  'ddi:DB00186DB00695',
#  'ddi:DB00186DB00773',
#  'ddi:DB00186DB00813',
#  'ddi:DB00186DB00997',
#  'ddi:DB00186DB01060',
#  'ddi:DB00186DB01076',
#  'ddi:DB00186DB01137',
#  'ddi:DB00186DB01229',
#  'ddi:DB00193DB00186',
#  'ddi:DB00193DB00316',
#  'ddi:DB00193DB00331',
#  'ddi:DB00193DB00338',
#  'ddi:DB00193DB00361',
#  'ddi:DB00193DB00531',
#  'ddi:DB00193DB00541',
#  'ddi:DB00193DB00641',
#  'ddi:DB00193DB00642',
#  'ddi:DB00193DB00773',
#  'ddi:DB00193DB00997',
#  'ddi:DB00193DB01060',
#  'ddi:DB00193DB01076',
#  'ddi:DB00193DB01137',
#  'ddi:DB00193DB01229',
#  'ddi:DB00193DB01248',
#  'ddi:DB00193DB09079',
#  'ddi:DB00316DB00331',
#  'ddi:DB00316DB00335',
#  'ddi:DB00316DB00338',
#  'ddi:DB00316DB00381',
#  'ddi:DB00316DB00437',
#  'ddi:DB00316DB00441',
#  'ddi:DB00316DB00515',
#  'ddi:DB00316DB00530',
#  'ddi:DB00316DB00531',
#  'ddi:DB00316DB00541',
#  'ddi:DB00316DB00635',
#  'ddi:DB00316DB00641',
#  'ddi:DB00316DB00642',
#  'ddi:DB00316DB00695',
#  'ddi:DB00316DB00762',
#  'ddi:DB00316DB00773',
#  'ddi:DB00316DB00863',
#  'ddi:DB00316DB00997',
#  'ddi:DB00316DB01001',
#  'ddi:DB00316DB01060',
#  'ddi:DB00316DB01076',
#  'ddi:DB00316DB01229',
#  'ddi:DB00316DB01248',
#  'ddi:DB00316DB06186',
#  'ddi:DB00316DB12001',
#  'ddi:DB00317DB00316',
#  'ddi:DB00317DB00338',
#  'ddi:DB00317DB00641',
#  'ddi:DB00317DB01050',
#  'ddi:DB00317DB01076',
#  'ddi:DB00331DB00338',
#  'ddi:DB00331DB00437',
#  'ddi:DB00331DB00440',
#  'ddi:DB00331DB00515',
#  'ddi:DB00331DB00641',
#  'ddi:DB00331DB00642',
#  'ddi:DB00331DB00863',
#  'ddi:DB00331DB01015',
#  'ddi:DB00331DB01060',
#  'ddi:DB00331DB01076',
#  'ddi:DB00331DB01229',
#  'ddi:DB00335DB00186',
#  'ddi:DB00335DB00331',
#  'ddi:DB00335DB00338',
#  'ddi:DB00335DB00421',
#  'ddi:DB00335DB00437',
#  'ddi:DB00335DB00441',
#  'ddi:DB00335DB00530',
#  'ddi:DB00335DB00541',
#  'ddi:DB00335DB00641',
#  'ddi:DB00335DB00642',
#  'ddi:DB00335DB00773',
#  'ddi:DB00335DB00997',
#  'ddi:DB00335DB01076',
#  'ddi:DB00335DB01229',
#  'ddi:DB00338DB00186',
#  'ddi:DB00338DB00193',
#  'ddi:DB00338DB00316',
#  'ddi:DB00338DB00317',
#  'ddi:DB00338DB00331',
#  'ddi:DB00338DB00335',
#  'ddi:DB00338DB00361',
#  'ddi:DB00338DB00381',
#  'ddi:DB00338DB00421',
#  'ddi:DB00338DB00437',
#  'ddi:DB00338DB00440',
#  'ddi:DB00338DB00441',
#  'ddi:DB00338DB00515',
#  'ddi:DB00338DB00530',
#  'ddi:DB00338DB00537',
#  'ddi:DB00338DB00541',
#  'ddi:DB00338DB00635',
#  'ddi:DB00338DB00641',
#  'ddi:DB00338DB00642',
#  'ddi:DB00338DB00695',
#  'ddi:DB00338DB00762',
#  'ddi:DB00338DB00773',
#  'ddi:DB00338DB00813',
#  'ddi:DB00338DB00863',
#  'ddi:DB00338DB00959',
#  'ddi:DB00338DB00997',
#  'ddi:DB00338DB01001',
#  'ddi:DB00338DB01015',
#  'ddi:DB00338DB01030',
#  'ddi:DB00338DB01050',
#  'ddi:DB00338DB01076',
#  'ddi:DB00338DB01137',
#  'ddi:DB00338DB01229',
#  'ddi:DB00338DB01233',
#  'ddi:DB00338DB01234',
#  'ddi:DB00338DB01248',
#  'ddi:DB00338DB08865',
#  'ddi:DB00338DB08916',
#  'ddi:DB00338DB09063',
#  'ddi:DB00338DB09079',
#  'ddi:DB00338DB09330',
#  'ddi:DB00338DB11363',
#  'ddi:DB00338DB11791',
#  'ddi:DB00338DB12001',
#  'ddi:DB00338DB12130',
#  'ddi:DB00338DB12267',
#  'ddi:DB00361DB00316',
#  'ddi:DB00361DB00331',
#  'ddi:DB00361DB00335',
#  'ddi:DB00361DB00338',
#  'ddi:DB00361DB00381',
#  'ddi:DB00361DB00437',
#  'ddi:DB00361DB00440',
#  'ddi:DB00361DB00515',
#  'ddi:DB00361DB00641',
#  'ddi:DB00361DB00959',
#  'ddi:DB00361DB01015',
#  'ddi:DB00361DB01076',
#  'ddi:DB00361DB01233',
#  'ddi:DB00361DB01234',
#  'ddi:DB00381DB00338',
#  'ddi:DB00381DB00641',
#  'ddi:DB00381DB00773',
#  'ddi:DB00381DB01076',
#  'ddi:DB00381DB01229',
#  'ddi:DB00381DB01248',
#  'ddi:DB00421DB00335',
#  'ddi:DB00421DB00338',
#  'ddi:DB00421DB00437',
#  'ddi:DB00421DB00641',
#  'ddi:DB00421DB00695',
#  'ddi:DB00421DB00773',
#  'ddi:DB00421DB00958',
#  'ddi:DB00437DB00331',
#  'ddi:DB00437DB00338',
#  'ddi:DB00437DB00440',
#  'ddi:DB00437DB00635',
#  'ddi:DB00437DB00641',
#  'ddi:DB00437DB00813',
#  'ddi:DB00437DB01001',
#  'ddi:DB00437DB01015',
#  'ddi:DB00437DB01076',
#  'ddi:DB00437DB01229',
#  'ddi:DB00440DB00331',
#  'ddi:DB00440DB00338',
#  'ddi:DB00440DB00437',
#  'ddi:DB00440DB00641',
#  'ddi:DB00440DB01015',
#  'ddi:DB00440DB01076',
#  'ddi:DB00440DB01229',
#  'ddi:DB00441DB00338',
#  'ddi:DB00441DB00641',
#  'ddi:DB00441DB00863',
#  'ddi:DB00441DB01001',
#  'ddi:DB00515DB00193',
#  'ddi:DB00515DB00335',
#  'ddi:DB00515DB00338',
#  'ddi:DB00515DB00361',
#  'ddi:DB00515DB00641',
#  'ddi:DB00515DB00642',
#  'ddi:DB00515DB00813',
#  'ddi:DB00515DB00863',
#  'ddi:DB00515DB00904',
#  'ddi:DB00515DB01001',
#  'ddi:DB00515DB01050',
#  'ddi:DB00515DB01076',
#  'ddi:DB00515DB01137',
#  'ddi:DB00515DB01233',
#  'ddi:DB00530DB00186',
#  'ddi:DB00530DB00338',
#  'ddi:DB00530DB00641',
#  'ddi:DB00530DB00642',
#  'ddi:DB00530DB01050',
#  'ddi:DB00530DB01076',
#  'ddi:DB00531DB00186',
#  'ddi:DB00531DB00193',
#  'ddi:DB00531DB00316',
#  'ddi:DB00531DB00331',
#  'ddi:DB00531DB00335',
#  'ddi:DB00531DB00338',
#  'ddi:DB00531DB00541',
#  'ddi:DB00531DB00641',
#  'ddi:DB00531DB00642',
#  'ddi:DB00531DB00997',
#  'ddi:DB00531DB01001',
#  'ddi:DB00531DB01050',
#  'ddi:DB00531DB01076',
#  'ddi:DB00531DB01137',
#  'ddi:DB00531DB01233',
#  'ddi:DB00537DB00642',
#  'ddi:DB00541DB00186',
#  'ddi:DB00541DB00193',
#  'ddi:DB00541DB00331',
#  'ddi:DB00541DB00335',
#  'ddi:DB00541DB00641',
#  'ddi:DB00541DB00997',
#  'ddi:DB00541DB01076',
#  'ddi:DB00541DB01137',
#  'ddi:DB00541DB01233',
#  'ddi:DB00641DB00193',
#  'ddi:DB00641DB00331',
#  'ddi:DB00641DB00335',
#  'ddi:DB00641DB00338',
#  'ddi:DB00641DB00421',
#  'ddi:DB00641DB00437',
#  'ddi:DB00641DB00440',
#  'ddi:DB00641DB00441',
#  'ddi:DB00641DB00541',
#  'ddi:DB00641DB00642',
#  'ddi:DB00641DB00773',
#  'ddi:DB00641DB00863',
#  'ddi:DB00641DB00997',
#  'ddi:DB00641DB01015',
#  'ddi:DB00641DB01076',
#  'ddi:DB00641DB01101',
#  'ddi:DB00641DB01229',
#  'ddi:DB00641DB01248',
#  'ddi:DB00641DB08916',
#  'ddi:DB00641DB09079',
#  'ddi:DB00641DB09330',
#  'ddi:DB00642DB00338',
#  'ddi:DB00642DB00515',
#  'ddi:DB00642DB00813',
#  'ddi:DB00695DB00186',
#  'ddi:DB00695DB00316',
#  'ddi:DB00695DB00331',
#  'ddi:DB00695DB00335',
#  'ddi:DB00695DB00361',
#  'ddi:DB00695DB00642',
#  'ddi:DB00695DB00958',
#  'ddi:DB00695DB01030',
#  'ddi:DB00695DB01076',
#  'ddi:DB00762DB00641',
#  'ddi:DB00773DB00186',
#  'ddi:DB00773DB00193',
#  'ddi:DB00773DB00331',
#  'ddi:DB00773DB00335',
#  'ddi:DB00773DB00338',
#  'ddi:DB00773DB00381',
#  'ddi:DB00773DB00515',
#  'ddi:DB00773DB00863',
#  'ddi:DB00773DB01001',
#  'ddi:DB00773DB01050',
#  'ddi:DB00773DB01060',
#  'ddi:DB00773DB01076',
#  'ddi:DB00773DB01137',
#  'ddi:DB00773DB01233',
#  'ddi:DB00798DB00331',
#  'ddi:DB00798DB00338',
#  'ddi:DB00798DB00437',
#  'ddi:DB00798DB00440',
#  'ddi:DB00798DB00641',
#  'ddi:DB00798DB01015',
#  'ddi:DB00798DB01076',
#  'ddi:DB00798DB01229',
#  'ddi:DB00813DB00338',
#  'ddi:DB00813DB00515',
#  'ddi:DB00813DB01076',
#  'ddi:DB00813DB01229',
#  'ddi:DB00863DB00317',
#  'ddi:DB00863DB00335',
#  'ddi:DB00863DB00338',
#  'ddi:DB00863DB00441',
#  'ddi:DB00863DB00530',
#  'ddi:DB00863DB00641',
#  'ddi:DB00863DB00642',
#  'ddi:DB00863DB01076',
#  'ddi:DB00863DB01229',
#  'ddi:DB00863DB06186',
#  'ddi:DB00904DB00515',
#  'ddi:DB00904DB00642',
#  'ddi:DB00904DB01050',
#  'ddi:DB00958DB00186',
#  'ddi:DB00958DB00193',
#  'ddi:DB00958DB00316',
#  'ddi:DB00958DB00331',
#  'ddi:DB00958DB00335',
#  'ddi:DB00958DB00338',
#  'ddi:DB00958DB00361',
#  'ddi:DB00958DB00437',
#  'ddi:DB00958DB00440',
#  'ddi:DB00958DB00441',
#  'ddi:DB00958DB00537',
#  'ddi:DB00958DB00635',
#  'ddi:DB00958DB00641',
#  'ddi:DB00958DB00642',
#  'ddi:DB00958DB00773',
#  'ddi:DB00958DB00813',
#  'ddi:DB00958DB00863',
#  'ddi:DB00958DB01001',
#  'ddi:DB00958DB01015',
#  'ddi:DB00958DB01050',
#  'ddi:DB00958DB01060',
#  'ddi:DB00958DB01076',
#  'ddi:DB00958DB01137',
#  'ddi:DB00958DB01229',
#  'ddi:DB00958DB06186',
#  'ddi:DB00958DB09214',
#  'ddi:DB00959DB01229',
#  'ddi:DB00997DB00186',
#  'ddi:DB00997DB00193',
#  'ddi:DB00997DB00316',
#  'ddi:DB00997DB00331',
#  'ddi:DB00997DB00335',
#  'ddi:DB00997DB00531',
#  'ddi:DB00997DB00541',
#  'ddi:DB00997DB00641',
#  'ddi:DB00997DB01076',
#  'ddi:DB00997DB01137',
#  'ddi:DB00997DB01233',
#  'ddi:DB01001DB00338',
#  'ddi:DB01001DB00515',
#  'ddi:DB01001DB00642',
#  'ddi:DB01001DB01050',
#  'ddi:DB01001DB01076',
#  'ddi:DB01001DB01233',
#  'ddi:DB01015DB00331',
#  'ddi:DB01015DB00338',
#  'ddi:DB01015DB00437',
#  'ddi:DB01015DB00440',
#  'ddi:DB01015DB00641',
#  'ddi:DB01015DB01076',
#  'ddi:DB01015DB01229',
#  'ddi:DB01030DB01076',
#  'ddi:DB01050DB00193',
#  'ddi:DB01050DB00316',
#  'ddi:DB01050DB00338',
#  'ddi:DB01050DB00515',
#  'ddi:DB01050DB00537',
#  'ddi:DB01050DB00642',
#  'ddi:DB01050DB00904',
#  'ddi:DB01050DB01001',
#  'ddi:DB01050DB01076',
#  'ddi:DB01050DB01229',
#  'ddi:DB01050DB01233',
#  'ddi:DB01050DB01248',
#  'ddi:DB01050DB09079',
#  'ddi:DB01050DB12130',
#  'ddi:DB01060DB00338',
#  'ddi:DB01060DB00515',
#  'ddi:DB01060DB00642',
#  'ddi:DB01076DB00207',
#  'ddi:DB01076DB01229',
#  'ddi:DB01101DB00338',
#  'ddi:DB01101DB01076',
#  'ddi:DB01137DB00186',
#  'ddi:DB01137DB00193',
#  'ddi:DB01137DB00642',
#  'ddi:DB01137DB00773',
#  'ddi:DB01212DB00515',
#  'ddi:DB01212DB01137',
#  'ddi:DB01229DB00207',
#  'ddi:DB01229DB00381',
#  'ddi:DB01233DB00338',
#  'ddi:DB01233DB00515',
#  'ddi:DB01233DB01001',
#  'ddi:DB01233DB01050',
#  'ddi:DB01234DB00186',
#  'ddi:DB01234DB00335',
#  'ddi:DB01234DB00338',
#  'ddi:DB01234DB00361',
#  'ddi:DB01234DB00515',
#  'ddi:DB01234DB00641',
#  'ddi:DB01234DB00642',
#  'ddi:DB01234DB00813',
#  'ddi:DB01234DB01229',
#  'ddi:DB01234DB01233',
#  'ddi:DB01234DB01248',
#  'ddi:DB01234DB08916',
#  'ddi:DB01234DB09330',
#  'ddi:DB01248DB00186',
#  'ddi:DB01248DB00316',
#  'ddi:DB01248DB00437',
#  'ddi:DB01248DB01076',
#  'ddi:DB01248DB09079',
#  'ddi:DB08865DB00316',
#  'ddi:DB08865DB01076',
#  'ddi:DB08911DB00338',
#  'ddi:DB08911DB01076',
#  'ddi:DB08912DB00338',
#  'ddi:DB08916DB00316',
#  'ddi:DB09063DB00316',
#  'ddi:DB09074DB00317',
#  'ddi:DB09079DB00316',
#  'ddi:DB09214DB00186',
#  'ddi:DB09214DB00193',
#  'ddi:DB09214DB00541',
#  'ddi:DB09214DB00773',
#  'ddi:DB09214DB00997',
#  'ddi:DB09214DB01137',
#  'ddi:DB09330DB00186',
#  'ddi:DB09330DB00316',
#  'ddi:DB09330DB00813',
#  'ddi:DB09330DB00863',
#  'ex:absorption_decrease',
#  'ex:effective',
#  'ex:excretion_decrease',
#  'ex:excretion_increase',
#  'ex:low_effect',
#  'ex:metabolism_decrease',
#  'ex:metabolism_increase',
#  'ex:serum_concentration_decrease',
#  'ex:serum_concentration_increase'}

# %% [markdown]
# #### Get in avg the similarity of one treatment with all the treatments of the same response

# %%
high_val_g1 = []
avg_sim_g1 = []
df1 = pd.DataFrame()
for e in entity[:-1]:
    # List of treatment with a response 'X' in the training set
    qres = g1.query(query_treatment_by_class('ex:low_effect'))
    treatment_response = sparql_results_to_df(qres)
    treatment_response['treatment'] = '<' + treatment_response['treatment'].astype(str) + '>'

    # Adding the treatment to compare
    df = treatment_response.append({'treatment':e}, ignore_index=True)
    df = list(df.treatment.values)

    # Get the embeddings of a list of entities
    graph = 'G1'
    entity_embedding_tensor, relation_embedding_tensor =  Auxiliary.get_learned_embeddings(model_g1)
    tf_dataset, triple_dataset = Auxiliary.load_dataset(path, graph+'/data/train_'+str(fold)+'.ttl')
    df_predicted_entities, new_df, df_g1 = Auxiliary.create_dataframe_predicted_entities(entity_embedding_tensor, df,
                                                                                         tf_dataset)
    new_df.replace('<http://example/Treatment/', '', regex=True, inplace=True)
    new_df.replace('>', '', regex=True, inplace=True)

    # Compute similarity matrix
    sim_matrix, high_val_overall = matrix_similarity(new_df, cosine_sim) # cosine_sim, euclidean_distance, manhattan_distance
#     sim_matrix = normalize_matrix(sim_matrix)

    # Get in avg the similarity of the entities
    e = e.replace('<http://example/Treatment/', '')
    e = e.replace('>', '')
#     summatory = sum(sim_matrix.sum().values)
#     avg_sim = (summatory - sim_matrix.shape[0]) / (sim_matrix.shape[0]*(sim_matrix.shape[0]-1))
    similarity = sim_matrix[sim_matrix.index.str.match(e)].drop(columns=e).max().values
    avg_sim = sum(similarity)/(sim_matrix.shape[0]-1)
    high_val = max(similarity)
    high_val_g1.append(high_val)
    avg_sim_g1.append(avg_sim)
    df = pd.DataFrame()
    df['sim_val'] = similarity
    df['treatment'] = e
    df['graph'] = '${\cal{T\_KG}}_{basic}$'
    df1 = pd.concat([df1, df])
    #df1[e] = similarity
    print(e, 'avg_sim:', avg_sim, 'high_val:', high_val, 'high_val_overall:', high_val_overall)
#     plot_treatment(new_df, '(' + e + ') Low_effect' , graph)
# Out:
# treatment225 avg_sim: 0.44746712499999974 high_val: 0.69221 high_val_overall: 0.78717
# treatment355 avg_sim: 0.5112635624999998 high_val: 0.75884 high_val_overall: 0.78717
# treatment312 avg_sim: 0.41764253124999984 high_val: 0.61926 high_val_overall: 0.78717
# treatment350 avg_sim: 0.47024296875000005 high_val: 0.68408 high_val_overall: 0.78717
# treatment102 avg_sim: 0.43441818750000005 high_val: 0.71403 high_val_overall: 0.78717

# %%
high_val_g2 = []
avg_sim_g2 = []
df2 = pd.DataFrame()
for e in entity[:-1]:
    # List of treatment with a response 'X' in the training set
    qres = g2.query(query_treatment_by_class('ex:low_effect'))
    treatment_response = sparql_results_to_df(qres)
    treatment_response['treatment'] = '<' + treatment_response['treatment'].astype(str) + '>'

    # Adding the treatment to compare
    df = treatment_response.append({'treatment':e}, ignore_index=True)
    df = list(df.treatment.values)
    
    # Get the embeddings of a list of entities
    graph = 'G2'
    entity_embedding_tensor, relation_embedding_tensor =  Auxiliary.get_learned_embeddings(model_g2)
    tf_dataset, triple_dataset = Auxiliary.load_dataset(path, graph+'/data/train_'+str(fold)+'.ttl')
    df_predicted_entities, new_df, df_g2 = Auxiliary.create_dataframe_predicted_entities(entity_embedding_tensor, df,
                                                                                         tf_dataset)
    new_df.replace('<http://example/Treatment/', '', regex=True, inplace=True)
    new_df.replace('>', '', regex=True, inplace=True)
    
    # Compute similarity matrix
    sim_matrix, high_val_overall = matrix_similarity(new_df, cosine_sim) # cosine_sim, euclidean_distance, manhattan_distance
#     sim_matrix = normalize_matrix(sim_matrix)

    # Get in avg the similarity of the entities
    e = e.replace('<http://example/Treatment/', '')
    e = e.replace('>', '')
#     summatory = sum(sim_matrix.sum().values)    
#     avg_sim = (summatory - sim_matrix.shape[0]) / (sim_matrix.shape[0]*(sim_matrix.shape[0]-1))
    similarity = sim_matrix[sim_matrix.index.str.match(e)].drop(columns=e).max().values
    avg_sim = sum(similarity)/(sim_matrix.shape[0]-1)
    high_val = max(similarity)
    high_val_g2.append(high_val)
    avg_sim_g2.append(avg_sim)
    
    df = pd.DataFrame()
    df['sim_val'] = similarity
    df['treatment'] = e
    df['graph'] = '$\cal{T\_KG}$'
    df2 = pd.concat([df2, df])
    #df2[e] = similarity
    print(e, 'avg_sim:', avg_sim, 'high_val:', high_val, 'high_val_overall:', high_val_overall)
#     plot_treatment(new_df, '(' + e + ') Low_effect' , graph)
# Out:
# treatment225 avg_sim: 0.47108509375 high_val: 0.70156 high_val_overall: 0.84582
# treatment355 avg_sim: 0.5315546874999999 high_val: 0.76278 high_val_overall: 0.84582
# treatment312 avg_sim: 0.47220281249999996 high_val: 0.64906 high_val_overall: 0.84582
# treatment350 avg_sim: 0.49700743750000037 high_val: 0.70302 high_val_overall: 0.84582
# treatment102 avg_sim: 0.45409565624999965 high_val: 0.72415 high_val_overall: 0.84582

# %%
df = pd.DataFrame(columns=['g1', 'g2'], index=entity[:-1])
df.index = df.index.str.replace('<http://example/Treatment/', '', regex=True)
df.index = df.index.str.replace('>', '', regex=True)

# %%
def plot_similarity(results, title):
    # set width of bar
    barWidth = 0.1
    # set height of bar (TransD_th85)
    bars1 = list(results['g1'].values)
    bars2 = list(results['g2'].values)
    
    # Set position of bar on X axis
    max_axis = len(bars1) * 0.25
    r1 = np.arange(0, max_axis, 0.25, float)
    #r1 = [0, 0.35, 0.7, 1.05, 1.4]
    r2 = [x + barWidth for x in r1]


    # Make the plot [color='#13505b'   color='#90bfc9'   color='#2d7f5e']
    plt.bar(r1, bars1, color=mcolors.CSS4_COLORS['rosybrown'], width=barWidth,
            edgecolor='white', label='${\cal{T\_KG}}_{basic}$')
    plt.bar(r2, bars2, color=mcolors.CSS4_COLORS['lightcoral'], width=barWidth,
            edgecolor='white', label='$\cal{T\_KG}$')

    # Add xticks on the middle of the group bars
    #plt.ylabel('Accuracy', fontweight='bold')
    #plt.ylim(0, 1)
#     y1 = np.arange(0, 1.1, 0.1, float)
#     plt.yticks(y1)
    treatment = list(results.index.values)
    plt.xticks([x + 0.05 for x in r1], treatment, fontsize='medium') #rotation='vertical'
    plt.title(title)
    # Create legend & Show graphic
    legend = plt.legend(loc='upper right', shadow=False, fontsize='small', ncol=1)
    #plt.savefig(metric + '_Threshold '+str(th)+".png", format='png', bbox_inches='tight', dpi=300)
    plt.savefig(fname='Plots/'+title+'.pdf', format='pdf', bbox_inches='tight')
    plt.show()

# %%
df['g1'] = high_val_g1
df['g2'] = high_val_g2
plot_similarity(df, 'Max Similarity Value')

# %%
df['g1'] = avg_sim_g1
df['g2'] = avg_sim_g2
plot_similarity(df, 'Avg Similarity Value')

# %%
df3 = pd.concat([df1, df2])

# %%
ax = sns.boxplot(x="treatment", y="sim_val", hue="graph", data=df3, 
                 palette=sns.color_palette("flare"), linewidth=1, saturation=0.7, width=0.8,)

# %%
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
ax.figure.savefig(fname='Plots/boxplot.pdf', format='pdf', bbox_inches='tight')

# %%
boxplot = df1.boxplot(column=list(df1.columns))
boxplot
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18520/83444416.py in <module>
# ----> 1 boxplot = df1.boxplot(column=list(df1.columns))
#       2 boxplot
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     509 ):
#     510     plot_backend = _get_plot_backend(backend)
# --> 511     return plot_backend.boxplot_frame(
#     512         self,
#     513         column=column,
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\boxplot.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     392     import matplotlib.pyplot as plt
#     393
# --> 394     ax = boxplot(
#     395         self,
#     396         column=column,
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\boxplot.py in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     369             columns = data.columns
#     370         else:
# --> 371             data = data[columns]
#     372
#     373         result = plot_group(columns, data.values.T, ax)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 1377             raise KeyError(f"{not_found} not in index")
#    1378
#    1379
#
# KeyError: "['treatment', 'graph'] not in index"

# %%
boxplot = df2.boxplot(column=list(df2.columns))
boxplot
# Out:
# <AxesSubplot:>
