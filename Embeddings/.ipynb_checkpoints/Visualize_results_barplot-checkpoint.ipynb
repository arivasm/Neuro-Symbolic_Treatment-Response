# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot_accuracy(results_th_g1,results_th_g2,results_th_g3, th, metric):
    # set width of bar
    barWidth = 0.1
    # set height of bar (TransD_th85)
    bars1 = list(results_th_g1.loc[results_th_g1.Threshold==85][metric].values)
    bars2 = list(results_th_g2.loc[results_th_g2.Threshold==65][metric].values)
    bars3 = list(results_th_g3.loc[results_th_g3.Threshold==65][metric].values) 
    
    #bars2 = list(results_threshold.loc[results_threshold.Threshold==th].avg_recall.values)
    #bars3 = list(results_threshold.loc[results_threshold.Threshold==th].avg_f_measure.values) 

    # Set position of bar on X axis
    # r1 = np.arange(len(bars1))
    r1 = [0, 0.35, 0.7, 1.05, 1.4]
    r2 = [x + barWidth for x in r1]
    r3 = [x + barWidth for x in r2]
    r4 = [x + barWidth for x in r3]

    # Make the plot
    plt.bar(r1, bars1, color='#13505b', width=barWidth, edgecolor='white', label='Graph 1')
    plt.bar(r2, bars2, color='#90bfc9', width=barWidth, edgecolor='white', label='Graph 2')
    plt.bar(r3, bars3, color='#2d7f5e', width=barWidth, edgecolor='white', label='Graph 3')

    # Add xticks on the middle of the group bars
    #plt.ylabel('Accuracy', fontweight='bold')
    plt.ylim(0, 1)

    plt.xticks([0.1, 0.45, 0.8, 1.15, 1.5], ['TransE', 'TransH', 'RotatE', 'TransD', 'TransR'])
    #plt.title(metric + ' & Threshold '+str(th))
    plt.title(metric)
    """
    for i, v in enumerate(bars1):
        plt.text(r1[i]-0.02, v+0.1, str(v), color='black', fontweight='bold', fontsize='x-small')
    for i, v in enumerate(bars2):
        plt.text(r2[i]-0.02, v+0.1, str(v), color='black', fontweight='bold', fontsize='x-small')
    for i, v in enumerate(bars3):
        plt.text(r3[i]-0.02, v+0.01, str(v), color='black', fontweight='bold', fontsize='x-small')
    """
    # Create legend & Show graphic
    legend = plt.legend(loc='upper right', shadow=False, fontsize='small', ncol=1)
    #plt.savefig(metric + '_Threshold '+str(th)+".png", format='png', bbox_inches='tight', dpi=300)
    #plt.savefig(metric + ".png", format='png', bbox_inches='tight', dpi=300)
    plt.savefig(metric + ".pdf", format='pdf', bbox_inches='tight')
    plt.show()

# %%
results_th_g1 = pd.read_csv('G1/results_threshold.csv', sep=';')
results_th_g2 = pd.read_csv('G2/results_threshold.csv', sep=';')
results_th_g3 = pd.read_csv('G3/results_threshold.csv', sep=';')
results_th_g3
# Out:
#      Model  Threshold  avg_precision  avg_recall  avg_f_measure
# 0   TransE         55       0.451544    0.580587       0.507988
# 1   TransH         55       0.401444    0.516128       0.451609
# 2   RotatE         55       0.525994    0.676340       0.591755
# 3   TransD         55       0.488069    0.627602       0.549099
# 4   TransR         55       0.425128    0.546138       0.478084
# 5   TransE         60       0.461385    0.527337       0.492150
# 6   TransH         60       0.405374    0.463289       0.432391
# 7   RotatE         60       0.542264    0.619838       0.578450
# 8   TransD         60       0.506398    0.578844       0.540192
# 9   TransR         60       0.427693    0.488384       0.456018
# 10  TransE         65       0.472237    0.472286       0.472251
# 11  TransH         65       0.409454    0.409472       0.409454
# 12  RotatE         65       0.557355    0.557506       0.557419
# 13  TransD         65       0.527735    0.527856       0.527784
# 14  TransR         65       0.430963    0.430598       0.430771
# 15  TransE         70       0.484405    0.415260       0.447166
# 16  TransH         70       0.413296    0.354285       0.381514
# 17  RotatE         70       0.569843    0.488611       0.526099
# 18  TransD         70       0.549550    0.471171       0.507340
# 19  TransR         70       0.432556    0.370479       0.399110
# 20  TransE         75       0.497961    0.355750       0.415002
# 21  TransH         75       0.415874    0.297098       0.346585
# 22  RotatE         75       0.587445    0.419806       0.489665
# 23  TransD         75       0.569692    0.407057       0.474825
# 24  TransR         75       0.434186    0.309919       0.361669
# 25  TransE         80       0.510845    0.291989       0.371579
# 26  TransH         80       0.419990    0.240055       0.305490
# 27  RotatE         80       0.603048    0.344831       0.438760
# 28  TransD         80       0.593203    0.339105       0.431519
# 29  TransR         80       0.436482    0.249266       0.317312
# 30  TransE         85       0.526249    0.225630       0.315836
# 31  TransH         85       0.425916    0.182593       0.255602
# 32  RotatE         85       0.619987    0.265957       0.372228
# 33  TransD         85       0.613724    0.263161       0.368361
# 34  TransR         85       0.436709    0.187092       0.261953

# %%
plot_accuracy(results_th_g1,results_th_g2,results_th_g3, 65, 'avg_precision')

# %%
plot_accuracy(results_th_g1,results_th_g2,results_th_g3, 65, 'avg_recall')

# %%
plot_accuracy(results_th_g1,results_th_g2,results_th_g3, 65, 'avg_f_measure')
