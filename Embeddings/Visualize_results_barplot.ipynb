# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot_accuracy(results_th_g1,results_th_g2,results_th_g3, path, metric):
    # set width of bar
    barWidth = 0.1
    # set height of bar (TransD_th85)
    bars1 = list(results_th_g1[metric].values)
    bars2 = list(results_th_g2[metric].values)
    bars3 = list(results_th_g3[metric].values) 
    

    # Set position of bar on X axis
    max_axis = len(bars1) * 0.35
    r1 = np.arange(0, max_axis, 0.35, float)
    #r1 = [0, 0.35, 0.7, 1.05, 1.4]
    r2 = [x + barWidth for x in r1]
    r3 = [x + barWidth for x in r2]
    r4 = [x + barWidth for x in r3]

    # Make the plot
    plt.bar(r1, bars1, color='#13505b', width=barWidth, edgecolor='white', label='Graph 1')
    plt.bar(r2, bars2, color='#90bfc9', width=barWidth, edgecolor='white', label='Graph 2')
    plt.bar(r3, bars3, color='#2d7f5e', width=barWidth, edgecolor='white', label='Graph 3')

    # Add xticks on the middle of the group bars
    #plt.ylabel('Accuracy', fontweight='bold')
    plt.ylim(0, 1)
    
    model = list(results_th_g1.Model.values)
    plt.xticks([x + 0.1 for x in r1], model, rotation='vertical')
    #plt.xticks([0.1, 0.45, 0.8, 1.15, 1.5], ['TransE', 'TransH', 'RotatE', 'TransD', 'TransR'])
    #plt.title(metric + ' & Threshold '+str(th))
    plt.title(metric)
    """
    for i, v in enumerate(bars1):
        plt.text(r1[i]-0.02, v+0.1, str(v), color='black', fontweight='bold', fontsize='x-small')
    for i, v in enumerate(bars2):
        plt.text(r2[i]-0.02, v+0.1, str(v), color='black', fontweight='bold', fontsize='x-small')
    for i, v in enumerate(bars3):
        plt.text(r3[i]-0.02, v+0.01, str(v), color='black', fontweight='bold', fontsize='x-small')
    """
    # Create legend & Show graphic
    legend = plt.legend(loc='upper right', shadow=False, fontsize='small', ncol=1)
    #plt.savefig(metric + '_Threshold '+str(th)+".png", format='png', bbox_inches='tight', dpi=300)
    plt.savefig(path + metric + ".png", format='png', bbox_inches='tight', dpi=300)
    plt.savefig(path + metric + ".pdf", format='pdf', bbox_inches='tight')
    plt.show()

# %%
results_th_g1 = pd.read_csv('G1/results_threshold_G1.csv', sep=';')
results_th_g2 = pd.read_csv('G2/results_threshold_G2.csv', sep=';')
results_th_g3 = pd.read_csv('G3/results_threshold.csv', sep=';')
results_th_g3
# Out:
#      Model  th_dec_eff     th_eff  avg_precision  avg_recall  avg_f_measure
# 0   TransE    9.655172  90.344828       0.851188    0.859024       0.855075
# 1   TransH    9.655172  90.344828       0.557454    0.560196       0.558816
# 2   RotatE    9.655172  90.344828       0.873103    0.881121       0.877080
# 3   TransD    9.655172  90.344828       0.695699    0.700804       0.698233
# 4     HolE    9.655172  90.344828       0.850526    0.858165       0.854316
# 5   TransR    9.655172  90.344828       0.859158    0.867121       0.863108
# 6       SE    9.655172  90.344828       0.794055    0.800859       0.797430
# 7       UM    9.655172  90.344828       0.798135    0.805003       0.801542
# 8    QuatE    9.655172  90.344828       0.875128    0.883233       0.879148
# 9   RESCAL    9.655172  90.344828       0.503068    0.504839       0.503949
# 10   ERMLP    9.655172  90.344828       0.585744    0.588877       0.587300

# %%
results_th_g2
# Out:
#      Model  th_dec_eff     th_eff  avg_precision  avg_recall  avg_f_measure
# 0   TransE    9.655172  90.344828         0.8632      0.8712         0.8672
# 1   TransH    9.655172  90.344828         0.5800      0.5825         0.5810
# 2   RotatE    9.655172  90.344828         0.8935      0.9018         0.8976
# 3   TransD    9.655172  90.344828         0.7911      0.7980         0.7945
# 4     HolE    9.655172  90.344828         0.8707      0.8787         0.8746
# 5   TransR    9.655172  90.344828         0.8738      0.8820         0.8778
# 6       SE    9.655172  90.344828         0.8867      0.8950         0.8908
# 7       UM    9.655172  90.344828         0.8580      0.8659         0.8619
# 8    QuatE    9.655172  90.344828         0.8772      0.8853         0.8812
# 9   RESCAL    9.655172  90.344828         0.5091      0.5110         0.5100
# 10   ERMLP    9.655172  90.344828         0.7226      0.7281         0.7253

# %%
plot_accuracy(results_th_g1,results_th_g2,results_th_g3, 'Plots/', 'avg_precision')

# %%
plot_accuracy(results_th_g1,results_th_g2,results_th_g3, 'Plots/', 'avg_recall')

# %%
plot_accuracy(results_th_g1,results_th_g2,results_th_g3, 'Plots/', 'avg_f_measure')
