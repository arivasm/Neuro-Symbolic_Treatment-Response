# %%
import os
import gzip
import collections
import xml.etree.ElementTree as ET
import pandas as pd

# %% [markdown]
# # Load drugbank database

# %%
xml_path = os.path.join('../../PhD_study/DDI_corpus/download', 'full database.xml.gz')
with gzip.open(xml_path) as xml_file:
    tree = ET.parse(xml_file)
root = tree.getroot()

# %% [markdown]
# # Extract 'pubchem_id' from each drug

# %%
ns = '{http://www.drugbank.ca}'
pubchem_id_template = "{ns}external-identifiers/{ns}external-identifier[{ns}resource='PubChem Compound']/{ns}identifier"

rows = list()
not_inchi=0
for i, drug in enumerate(root):
    row = collections.OrderedDict()
    assert drug.tag == ns + 'drug'
    row['drugbank_id'] = drug.findtext(ns + "drugbank-id[@primary='true']")
    row['name'] = drug.findtext(ns + "name")    
    row['pubchem_id'] = drug.findtext(pubchem_id_template.format(ns = ns))
    if row['pubchem_id'] == None:
        continue
    rows.append(row)
    
columns = ['drugbank_id', 'name', 'pubchem_id']
drugbank_df = pd.DataFrame.from_dict(rows)[columns]
drugbank_df['pubchem_id'] = drugbank_df['pubchem_id'].astype(int)
drugbank_df.to_csv('dataset/drugbank_pubchem_id.csv', index=False)
display(drugbank_df.shape, drugbank_df.head())
# Out:
# (8725, 3)
#   drugbank_id          name  pubchem_id
# 0     DB00006   Bivalirudin    16129704
# 1     DB00014     Goserelin     5311128
# 2     DB00027  Gramicidin D    45267103
# 3     DB00050    Cetrorelix    25074887
# 4     DB00080    Daptomycin    16134395

# %% [markdown]
# ## Load dataset of drug with 'pubchem_id' extracted via pubchempy.get_compounds(inchi)

# %%
drugbank_cid = pd.read_csv('dataset/drugbank_cid.csv')

drug_pubchem_id = pd.concat([drugbank_df, drugbank_cid])
drug_pubchem_id.drop_duplicates(keep='first', inplace=True)
drug_pubchem_id = drug_pubchem_id.sort_values(["drugbank_id"], ascending = (True))
drug_pubchem_id
# Out:
#       drugbank_id                   name  pubchem_id
# 0         DB00006            Bivalirudin    16129704
# 0         DB00006            Bivalirudin   101041682
# 1         DB00007             Leuprolide      657181
# 1         DB00014              Goserelin     5311128
# 2         DB00027           Gramicidin D    45267103
# ...           ...                    ...         ...
# 11086     DB16735               PAT-1251   122536283
# 11087     DB16737                 MM3122   155925845
# 11088     DB16739                 MK-886     3651377
# 11089     DB16741  Bortezomib D-mannitol    12990536
# 11090     DB16745               PXT 3003    71767809
#
# [11934 rows x 3 columns]

# %% [markdown]
# # STITCH to DrugBank mapping

# %%
def stitch_flat_to_pubchem(cid):
    assert cid.startswith('CID')
    return int(cid[3:]) - 1e8


def stitch_stereo_to_pubchem(cid):
    assert cid.startswith('CID')
    return int(cid[3:])

# %% [markdown]
# ## meddra_freq.tsv.gz

# %%
columns = ['stitch_id_flat', 'stitch_id_sterio', 'umls_cui_from_label', 'placebo', 'frequency', 'lower', 'upper',
           'meddra_type', 'umls_cui_from_meddra', 'side_effect_name',]
freq_df = pd.read_table('../../PhD_study/DDI_corpus/SIDER_data/meddra_freq.tsv.gz', names=columns)
freq_df.head(2)
# Out:
#   stitch_id_flat stitch_id_sterio umls_cui_from_label placebo frequency  \
# 0   CID100000085     CID000010917            C0000737     NaN       21%
# 1   CID100000085     CID000010917            C0000737     NaN       21%
#
#    lower  upper meddra_type umls_cui_from_meddra side_effect_name
# 0   0.21   0.21         LLT             C0000737   Abdominal pain
# 1   0.21   0.21          PT             C0000737   Abdominal pain

# %%
freq_df['pubchem_id'] = freq_df.stitch_id_sterio.map(stitch_stereo_to_pubchem)
freq_df = drug_pubchem_id.merge(freq_df)
display(freq_df.shape, freq_df.head())
# Out:
# (214269, 13)
#   drugbank_id         name  pubchem_id stitch_id_flat stitch_id_sterio  \
# 0     DB00006  Bivalirudin    16129704   CID116129704     CID016129704
# 1     DB00006  Bivalirudin    16129704   CID116129704     CID016129704
# 2     DB00006  Bivalirudin    16129704   CID116129704     CID016129704
# 3     DB00006  Bivalirudin    16129704   CID116129704     CID016129704
# 4     DB00006  Bivalirudin    16129704   CID116129704     CID016129704
#
#   umls_cui_from_label placebo frequency  lower  upper meddra_type  \
# 0            C0000737     NaN      0.8%  0.008  0.008         LLT
# 1            C0000737     NaN      0.8%  0.008  0.008          PT
# 2            C0000737     NaN      0.8%  0.008  0.008          PT
# 3            C0000737     NaN        1%  0.010  0.010         LLT
# 4            C0000737     NaN        1%  0.010  0.010          PT
#
#   umls_cui_from_meddra       side_effect_name
# 0             C0000737         Abdominal pain
# 1             C0000737         Abdominal pain
# 2             C0687713  Gastrointestinal pain
# 3             C0000737         Abdominal pain
# 4             C0000737         Abdominal pain

# %%
len(freq_df.drugbank_id.unique())
# Out:
# 712

# %%
len(freq_df.stitch_id_sterio.unique())
# Out:
# 713

# %%
freq_df = freq_df.drop(columns=['placebo', 'frequency', 'meddra_type', 'umls_cui_from_meddra'])
freq_df.drop_duplicates(keep='first', inplace=True)
freq_df
# Out:
#        drugbank_id                     name  pubchem_id stitch_id_flat  \
# 0          DB00006              Bivalirudin    16129704   CID116129704
# 2          DB00006              Bivalirudin    16129704   CID116129704
# 3          DB00006              Bivalirudin    16129704   CID116129704
# 5          DB00006              Bivalirudin    16129704   CID116129704
# 6          DB00006              Bivalirudin    16129704   CID116129704
# ...            ...                      ...         ...            ...
# 214259     DB15351  Dihematoporphyrin ether       57166   CID100057166
# 214261     DB15351  Dihematoporphyrin ether       57166   CID100057166
# 214263     DB15351  Dihematoporphyrin ether       57166   CID100057166
# 214265     DB15351  Dihematoporphyrin ether       57166   CID100057166
# 214267     DB15351  Dihematoporphyrin ether       57166   CID100057166
#
#        stitch_id_sterio umls_cui_from_label     lower     upper  \
# 0          CID016129704            C0000737  0.008000  0.008000
# 2          CID016129704            C0000737  0.008000  0.008000
# 3          CID016129704            C0000737  0.010000  0.010000
# 5          CID016129704            C0000737  0.010000  0.010000
# 6          CID016129704            C0000737  0.047663  0.047663
# ...                 ...                 ...       ...       ...
# 214259     CID000057166            C1536009  0.080000  0.080000
# 214261     CID000057166            C3263723  0.144928  0.144928
# 214263     CID000057166            C3263723  0.191781  0.191781
# 214265     CID000057166            C3263723  0.191824  0.191824
# 214267     CID000057166            C3263723  0.191919  0.191919
#
#              side_effect_name
# 0              Abdominal pain
# 2       Gastrointestinal pain
# 3              Abdominal pain
# 5       Gastrointestinal pain
# 6              Abdominal pain
# ...                       ...
# 214259     Oesophageal oedema
# 214261                 Injury
# 214263                 Injury
# 214265                 Injury
# 214267                 Injury
#
# [116371 rows x 9 columns]

# %%
freq_df = freq_df.sort_values('upper', ascending=False).drop_duplicates(['drugbank_id', 'pubchem_id', 'umls_cui_from_label'])
freq_df
# Out:
#        drugbank_id                       name  pubchem_id stitch_id_flat  \
# 21264      DB00268                 Ropinirole        5095   CID100005095
# 124612     DB00915                 Amantadine        2130   CID100002130
# 124638     DB00915                 Amantadine        2130   CID100002130
# 124633     DB00915                 Amantadine        2130   CID100002130
# 124631     DB00915                 Amantadine        2130   CID100002130
# ...            ...                        ...         ...            ...
# 198916     DB06769               Bendamustine       65628   CID100065628
# 198840     DB06769               Bendamustine       65628   CID100065628
# 182868     DB01440  gamma-Hydroxybutyric acid       10413   CID100010413
# 182872     DB01440  gamma-Hydroxybutyric acid       10413   CID100010413
# 4941       DB00188                 Bortezomib      387447   CID100093860
#
#        stitch_id_sterio umls_cui_from_label  lower  upper  \
# 21264      CID000005095            C0018772   0.01    1.0
# 124612     CID000002130            C0085649   0.10    1.0
# 124638     CID000002130            C0235198   0.01    1.0
# 124633     CID000002130            C0234518   0.01    1.0
# 124631     CID000002130            C0233571   0.01    1.0
# ...                 ...                 ...    ...    ...
# 198916     CID000065628            C0027424   0.00    0.0
# 198840     CID000065628            C0013395   0.00    0.0
# 182868     CID000010413            C0700590   0.00    0.0
# 182872     CID000010413            C0947912   0.00    0.0
# 4941       CID000387447            C0232492   0.00    0.0
#
#             side_effect_name
# 21264       Hearing impaired
# 124612     Oedema peripheral
# 124638  Cerebration impaired
# 124633            Dysarthria
# 124631             Agitation
# ...                      ...
# 198916      Nasal congestion
# 198840             Dyspepsia
# 182868    Sweating increased
# 182872            Myasthenia
# 4941    Abdominal pain upper
#
# [42914 rows x 9 columns]

# %%
freq_df.to_csv('dataset/drugbank_freq_side_effect.csv', index=False)
